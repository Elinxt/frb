# %% [markdown]
# # Модули

# %%
import os
import math
import xlwt
import xlrd
import glob
import datetime
import openpyxl
import xlsxwriter

from lmfit import Model
from struct import unpack
from collections import deque
from copy import copy, deepcopy
from openpyxl import load_workbook
from datetime import datetime, date, time
from lmfit.models import GaussianModel, PowerLawModel, LognormalModel


import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from tqdm import tqdm

from numpy import random, mean, var, std, median,arange
from IPython import get_ipython
from matplotlib import mlab
import matplotlib.ticker as ticker

from astropy.utils import iers
from astropy.time import Time, TimeDelta
from astropy.coordinates import Angle
from astropy import units as u
from bisect import bisect_left
from scipy import signal, misc, linalg as lng

plt.rcParams.update({'figure.max_open_warning': 0})
iers.conf.auto_download = False
import matplotlib
# %matplotlib notebook
plt.rcParams.update({'figure.max_open_warning': 0})
matplotlib.use('nbagg')

# %% [markdown]
# # Ввод параметров

# %%
path_name = str('some_frb')
name_source = path_name
data_process = str('')
data_lenth = 'short'
reg = 'N1'

try:
    path = '/home/oem/work/' + path_name + '/'
    os.mkdir(path)
    
except Exception as e: 
    print('Такая папка уже существует.')

alfa = [5,34,0]
delta = [41,42,0]

DM = 247
DM = DM*10**-3


#8.10.2015 0521 + 33.1 570 ± 5 6.2 1.4 3500 0.275 0.273

# B0525+21  sr68       05:28:52.264         9  ywml10     +22:00:04            2  ywml10     3.74553925030            3  ywml10     50.8695       13  bkk+16 
# B0523+11      mlt+78     05:25:56.4483       11  hlk+04     +11:15:19.08         7  hlk+04     0.35443759451370        13  hlk+04     79.418 
# J0519+44      hrk+08     05:19                0  hrk+08     0.515                    0  hrk+08     52             0  hrk+08
# Out:
# Такая папка уже существует.

# %% [markdown]
# # Звездное время

# %%
def star_time(time, delta):
    t1900 = Time('1900-01-01T12:00:00', format='isot', precision=7)
    utd = (time.jd - t1900.jd + 1)
    utd2 = utd - 36525
    utcen = utd2 / 36525
    ts0 = 6 * 3600 + 41 * 60 + 50.54841 + 8640184.812866 * utcen + 0.093104 * utcen * utcen - 6.2e-6 * utcen * utcen * utcen
    td0 = ts0 / 86400
    td0 = td0 + ((time.datetime.hour + time.datetime.minute / 60 +
                  time.datetime.second / 3600) / 24) * 1.002737909
    
    td0 = td0 - int(td0)
    if td0 < 0:
        td0 += 1
    tdh = td0 * 24
    return tdh

def culmination_utc_to_sideral(time):
    a = (str(time)[0:11] + '00:00:00.0000000')
    time2 = Time(a, format='isot', precision=7)
    
    #time2 = Time('2018-08-25T00:00:00.000', format='isot', precision=7)
    s0 = star_time(time2, delta)
    hour = time.datetime.hour + time.datetime.minute/60 + time.datetime.second/3600
    s_hour = hour / (1 - 236.55/(24*3600))#;    // столько звездных часов прошло с начала дня до кульминации
    if (s_hour < 0):
        s_hour = s_hour + 24.
    s_culm = s0 + s_hour
    if ( s_culm > 24.):
        s_culm = s_culm - 24.
    return s_culm

def add_lambda_bsa1(s_culm):
    lambda_grad = (37 + 37 / 60 + 48 / 3600) / 360
    lambda_hour = lambda_grad * 24
    s_culm1 = s_culm + lambda_hour
    if (s_culm1 < 0):
        s_culm1 = s_culm1 + 24
    return s_culm1

def add_incline_bsa1(alfa, delta):
    fi = 0.956829
    be = 0.008436
    rg = 1.7453292e-2
    rm = 2.90888e-4
    rs = 4.8481368e-6
    am = 46.1*rs
    an = 20.0*rs
    alfa = (alfa[0] * rg + alfa[1] * rm + alfa[2] * rs) * 15
    delta = (delta[0] * rg + delta[1] * rm + delta[2] * rs)
    
    aa = (((np.sin(fi))**2) * ((np.cos(be))**2) + ((np.cos(fi))**2))
    bb = 2 * (np.sin(fi)) * (np.cos(be)) * np.sin(delta)
    cc = (np.sin(delta))**2 - (np.cos(fi))**2

    x = (bb + ((bb)**2 - 4. * aa * cc)**0.5) / (2 * aa)
    y = x * np.sin(be) / np.cos(delta)
    z = (1. - (y * y))**0.5

    t = y / z
    dalfa = np.arctan(t)
    alfa = alfa + dalfa

    if alfa < 0:
        alfa = alfa + 2 * np.pi

    RG = (np.pi / 180.)
    RM = (np.pi / 180.) / 60.
    RS = (np.pi / 180.) / 3600.
    hour = int(alfa / (RG * 15))
    mint = int((alfa - (hour * RG * 15.)) / (RM * 15.))
    sec = (alfa - hour * RG * 15. - mint * RM * 15.) / (RS * 15.)
    hour = hour + mint / 60. + sec / 3600;
    while (hour >= 24):
        hour = hour - 24
    return hour

def precess1(coord, time, delta):
    RG = (np.pi / 180.)
    RM = (np.pi / 180.) / 60.
    RS = (np.pi / 180.) / 3600.
    am = 46.1 * RS
    an = 20.4 * RS
    alfa = (int(coord[0]) + int(coord[1]) / 60 + coord[2] / 3600) * 15 * np.pi / 180
    delta = (int(delta[0]) + int(delta[1]) / 60 +
             delta[2] / 3600) * np.pi / 180
    
    t2000 = Time('2000-01-01T12:00:00')
    t = (time.jd - t2000.jd)/365
    alfa1 = alfa
    delta1 = delta

    for i in range(2):
        alf = alfa - (am + an * np.sin(alfa1) * np.tan(delta1)) * t
        del1 = delta - (an * np.cos(alfa1)) * t
        alfa1 = (alf + alfa) / 2
        delta1 = (del1 + delta) / 2
        
    hour = int(alf / (RG * 15))
    mint = int((alf - (hour * RG * 15.)) / (RM * 15))
    sec = (alf - hour * RG * 15 - mint * RM * 15) / (RS * 15)
    
    while (hour >= 24):
        hour = hour - 24
        
    alfa2 = [hour, mint, sec]
    grad0 = del1 * 180. / np.pi
    igrad = int(grad0)
    min0  = (grad0 - igrad)*60
    imin  = int((grad0 - igrad)*60)
    sec = (min0 - imin)*60
    delta = [igrad, imin, sec]

    if hour >= 24:
        hour = hour - 24
    
    alfa2 = hour +  mint/60 +  sec/3600
    return alfa2, delta

def my_sidereal_time(time, delta):
    s_culm = culmination_utc_to_sideral(time)
    s_culm = add_lambda_bsa1(s_culm)
    alfa = [0, 0, 0]
    alfa[0] = int(s_culm)
    alfa[1] = int((s_culm - int(s_culm)) * 60)
    a = (s_culm - int(s_culm)) * 60
    alfa[2] = (a - int(a)) * 60
    s_culm = add_incline_bsa1(alfa, delta)
    mint = int((s_culm - int(s_culm)) * 60)
    a = (s_culm - int(s_culm)) * 60
    sec = (a - int(a)) * 60
    ihour = int(s_culm)
    imin = int(mint)
    day = 0
    while (ihour >= 24):
        ihour = ihour - 24
        day += 1
    coord = [ihour, imin, sec]
    alfa2, delta = precess1(coord, time, delta)
    return alfa2

# %% [markdown]
# # Список файлов и открытие

# %%
def read_head_pntr(filename):
    head = {}
    with open(filename, 'rb') as F:
        for i in range(16):
            line = F.readline()
            a, *b = line.decode("utf-8").strip('\n').split()
            head[a] = b
    return head

def time_begin_and_end(head):

    if 'UTC' in head['date_begin']:
        # begin
        day, month, year = head['date_begin'][2].split('.')
        hour, minute, second = head['time_begin'][2].split(':')
        isot_time = (year + '-' + month + '-' + day + 'T' + hour + ':' +
                     minute + ':' + second)
        time_start = Time(isot_time,
                          format='isot',
                          location=('37.63d', '54.8394444444d'),
                          precision=3)

        #time_start -= 4*u.hour #ПРОВЕРИТЬ

        # end
        day, month, year = head['date_end'][0].split('.')
        hour, minute, second = head['time_end'][0].split(':')
        isot_time = (year + '-' + month + '-' + day + 'T' + hour + ':' +
                     minute + ':' + second)
        time_end = Time(isot_time,
                        format='isot',
                        location=('37.63d', '54.8394444444d'),
                        precision=3)

        time_end -= 4 * u.hour
    else:
        # begin
        day, month, year = head['date_begin'][0].split('.')
        hour, minute, second = head['time_begin'][0].split(':')
        isot_time = (year + '-' + month + '-' + day + 'T' + hour + ':' +
                     minute + ':' + second)
        time_start = Time(isot_time,
                          format='isot',
                          location=('37.63d', '54.8394444444d'),
                          precision=3)
        time_start -= 4 * u.hour
        # end
        day, month, year = head['date_end'][0].split('.')
        hour, minute, second = head['time_end'][0].split(':')
        isot_time = (year + '-' + month + '-' + day + 'T' + hour + ':' +
                     minute + ':' + second)
        time_end = Time(isot_time,
                        format='isot',
                        location=('37.63d', '54.8394444444d'),
                        precision=3)

        time_end -= 4 * u.hour

    return time_start, time_end

def module_ray():
    
    def find_nearest(array, value):
    
        array = np.asarray(array)
        idx = (np.abs(array - value)).argmin()

        return array[idx], idx
    
    
    table = pd.read_csv('/home/oem/work/beams_lpa.csv', sep=';')
    dec_obj = Angle(str(delta[0])+'d'+str(delta[1]) + 'm' + str(delta[2]) +'s') 
    der_ray, idx = find_nearest(table['110.04'], dec_obj.value) 
    
    if dec_obj.value <= 21.40:
        reg = 'N2'
    else:
        reg = 'N1'
            
    module = table.iloc[idx]['module']
    ray = table.iloc[idx]['ray']
    
    return module, ray, reg

def file_list(data,reg):
    
    if data_lenth == 'long':
        direct = '/home/oem/work/files/*' + reg + '*.pnthr'
    else:
        direct = '/home/oem/work/files/*' + reg + '*.pnt'

    F = glob.glob(direct)
    F.sort()

    FILE = []
    for file in F:
        try:
            head = read_head_pntr(file)
            time_start, time_end = time_begin_and_end(head)
            sidereal_time_start = my_sidereal_time(time_start, delta)
            sidereal_time_end = my_sidereal_time(time_end, delta)
            source = alfa[0] + alfa[1]/60 + alfa[2]/3600
            if source > sidereal_time_start and source < sidereal_time_end:
                FILE.append(file)
        except Exception as e:
            print(e)
            continue
    return FILE

def read_pntr(file):
    head = {}
    with open(file, 'rb') as f:
        for i in range(16):
            line = f.readline()
            a, *b = line.decode("utf-8").strip('\n').split()
            head[a] = b

        data = np.fromfile(f, dtype=np.float32)
        data = data.reshape(
            int(head['npoints'][0]), 6, 8, len(head['fbands'])+1)

    return head, data

# %% [markdown]
# # Сшивка файлов

# %%
def on_the_border(B, data, file, index1, index2, point_time, MEAN, reg, head):
    
    print('Сшитый файл_1')
    

    data_32_ray2 = [[
        data[q][module - 1][ray - 1][x] for q in range(int(head['npoints'][0]))
    ] for x in (range(len(head['fbands']) + 1))]

    for i in (range(len(head['fbands']) + 1)):
        data_32_ray2[i] = data_32_ray2[i][index1:B]

    if data_lenth == 'long':
        direct = '/home/oem/work/files/*' + reg + '*.pnthr'
    else:
        direct = '/home/oem/work/files/*' + reg + '*.pnt'

    F = glob.glob(direct)
    F.sort()

    A = F.index(file)
    file2 = F[A + 1]
    print(file2)

    head2, data2 = read_pntr(file2)
    time_start2, time_end2 = time_begin_and_end(head2)

    data_32_2_ray2 = [[
        data2[q][module - 1][ray - 1][x]
        for q in range(int(head['npoints'][0]))
    ] for x in (range(len(head['fbands']) + 1))]

    for i in (range(len(head['fbands']) + 1)):
        data_32_2_ray2[i] = data_32_2_ray2[i][:int((MEAN - index1) -
                                                   (B - MEAN))]

    data_cut_ray2 = [0 for i in range(len(head['fbands']) + 1)]
    for i in range(len(head['fbands']) + 1):
        data_cut_ray2[i] = data_32_ray2[i] + data_32_2_ray2[i]

    point_time = point_time[index1:B] + point_time[:int((MEAN - index1) -
                                                        (B - MEAN))]
    data_32_ray2 = data_cut_ray2

    return data_32_ray2, time_start2, point_time

"""def on_the_border_2(number_of_points, data, file, index1, index2, point_time, MEAN, reg, head):
    
    print('Сшитый файл_2')
    data_32_ray2 = [[
        data[q][module - 1][ray - 1][x] for q in range(int(head['npoints'][0]))
    ] for x in (range(len(head['fbands']) + 1))]

    for i in (range(len(head['fbands']) + 1)):
        data_32_ray2[i] = data_32_ray2[i][:index2]

    if data_lenth == 'long':
        direct = '/home/oem/work/files/*' + reg + '*.pnthr'
    else:
        direct = '/home/oem/work/files/*' + reg + '*.pnt'

    F = glob.glob(direct)
    F.sort()
    
    A = F.index(file)
    file2 = F[A - 1]

    head2, data2 = read_pntr(file2)
    time_start2, time_end2 = time_begin_and_end(head2)

    data_32_2_ray2 = [[
        data2[q][module - 1][ray - 1][x]
        for q in range(int(head['npoints'][0]))
    ] for x in (range(len(head['fbands']) + 1))]
    
    

    for i in (range(len(head['fbands']) + 1)):
        data_32_2_ray2[i] = data_32_2_ray2[i][int(number_of_points -
                                                  (index2 -
                                                   (index2 - MEAN))):int(number_of_points)]
        
    
    data_cut_ray2 = [0 for i in range(len(head['fbands']) + 1)]
    print(len(data_32_2_ray2[0]),len(data_32_ray2[0]))
    
    for i in range(len(head['fbands']) + 1):
        data_cut_ray2[i] = data_32_2_ray2[i] + data_32_ray2[i]

    point_time = point_time[int(number_of_points - (
        index2 - (index2 - MEAN))):int(number_of_points)] + point_time[:int(index2)]
    data_32_ray2 = data_cut_ray2
    
    print(len((data_32_ray2[0])))
    
    return data_32_ray2, time_start2, point_time"""

def on_the_border_2(number_of_points, data, file, index1, index2, point_time, MEAN, reg, head):
    
    print('Сшитый файл_2')
    
    data_32_ray2 = [[
        data[q][module - 1][ray - 1][x] for q in range(int(head['npoints'][0]))
    ] for x in (range(len(head['fbands']) + 1))]

    for i in (range(len(head['fbands']) + 1)):
        data_32_ray2[i] = data_32_ray2[i][:index2]

    if data_lenth == 'long':
        direct = '/home/oem/work/files/*' + reg + '*.pnthr'
    else:
        direct = '/home/oem/work/files/*' + reg + '*.pnt'

    F = glob.glob(direct)
    F.sort()
    
    A = F.index(file)
    file2 = F[A - 1]

    head2, data2 = read_pntr(file2)
    time_start2, time_end2 = time_begin_and_end(head2)

    data_32_2_ray2 = [[
        data2[q][module - 1][ray - 1][x]
        for q in range(int(head['npoints'][0]))
    ] for x in (range(len(head['fbands']) + 1))]
    
    

    for i in (range(len(head['fbands']) + 1)):
        data_32_2_ray2[i] = data_32_2_ray2[i][int(number_of_points - abs(index1)):]
        
    print('индекс ', int(number_of_points - abs(index1)))
    
    data_cut_ray2 = [0 for i in range(len(head['fbands']) + 1)]
    
    for i in range(len(head['fbands']) + 1):
        data_cut_ray2[i] = data_32_2_ray2[i] + data_32_ray2[i]

    point_time = point_time[int(number_of_points - abs(index1)):] + point_time[:int(index2)]
    data_32_ray2 = data_cut_ray2
    print(len(data_32_ray2[0]))
    
    return data_32_ray2, time_start2, point_time

# %% [markdown]
# # Обработка

# %% [markdown]
# ## Открытие файла

# %%
FILE = file_list(data_lenth, reg)
print('Список файлов: ')
[print(i) for i in FILE]
file = FILE[1]
print('Обрабатываемый файл: ')
print(file)
# Out:
# Список файлов:
# /home/oem/work/files/181015_06_N1_00.pnt
# /home/oem/work/files/200916_08_N1_00.pnt
# Обрабатываемый файл:
# /home/oem/work/files/200916_08_N1_00.pnt
# /home/oem/work/work/lib/python3.8/site-packages/erfa/core.py:154: ErfaWarning: ERFA function "dtf2d" yielded 1 of "dubious year (Note 6)"
#   warnings.warn('ERFA function "{}" yielded {}'.format(func_name, wmsg),

# %%
module, ray,reg = module_ray()
head, data = read_pntr(file)
time_start, time_end = time_begin_and_end(head)

# %% [markdown]
# ## Функции

# %%
def moving_average(a, n=3):
    ret = np.cumsum(a, dtype=float)
    ret[n:] = ret[n:] - ret[:-n]
    b = ret[n - 1:] / n
    return b
    
def where(time_s, source):
    pos = bisect_left(time_s, source)
    before = time_s[pos - 1]
    after = time_s[pos]
    if after - source < source - before:
        return after
    else:
        return before
    
def flatter(array_before_subtraction, step = 50, pic = True):
    a = array_before_subtraction[0:int(len(array_before_subtraction)/step)*step]
    b = np.array(a)
    c = np.reshape(b, (round(len(b)/step),step))
    medians = []
    for i in range(len(c)):
        medians.append(np.median(c[i]))

    background_line = []
    for i in range(len(medians)-1):
        a = np.linspace(medians[i],medians[i+1],len(c[0]))
        for k in range(len(a)):
            background_line.append(a[k])
            
    b = b[:len(background_line)]
    array_after_subtraction = b - background_line
    if data_lenth == 'long':
        name_ch = '32 канала'
    else: 
        name_ch = '6 каналов'
    if pic == True:
        fig, ax = plt.subplots(figsize=(8, 6))
        plt.title(name_ch + ' DM = 0, before', size=20)
        plt.plot(b)
        plt.plot(background_line)
        plt.ylabel('amplitude (points)', size=15)
        plt.xlabel('time (points)', size=15)
        plt.show();

        

        fig, ax = plt.subplots(figsize=(8, 6))
        plt.title(name_ch + ' DM = 0, after', size=20)
        plt.plot(array_after_subtraction)
        plt.ylabel('amplitude (acp)', size=15)
        plt.xlabel('time (points)', size=15)
        plt.show();
    
    return array_after_subtraction

def scatter (x,t_s, t):
    a = []
    for i in range(len(x)):
        if x[i] < 0:
            a.append(0)
        else:
            a.append((1/t_s)*(np.exp(-x[i]/t_s)))
    return a

def pulse (x,a,b,s):
    c = []
    for i in range(len(x)):
        c.append(a*np.exp(-(((x[i] - b)**2)/(2*s**2))))
        
    return c

def averaging(a, step_averaging):
    b = []
    c = int(len(a)//step_averaging)*step_averaging
    a = a[:c]
    a = np.reshape(a, (int(len(a)//step_averaging), step_averaging))
    for i in range(len(a)):
        b.append(sum(a[i]))
    a = b
    return a

def infnorm(vector):
    norm = 0
    for i in range(len(vector)):
        if abs(vector[i]) > norm:
            norm = vector[i]
    return norm

def normalize(vector):
    norm = infnorm(vector)
    return [v / norm for v in vector]

# %% [markdown]
# ## Поиск источника в файле

# %%
b = str(head['date_begin'][0])
    
day,month,year = b.split('.')

t0 = int(year) + int(month) / 12 + int(day) / 365
source = alfa[0] + alfa[1] / 60 + alfa[2] / 3600

dt = TimeDelta(float(head['tresolution'][0])/1000, format='sec')
number_of_points = int(head['npoints'][0])
num = int(2401)
time_file = [(time_start + dt * i) for i in (range(0, number_of_points, num))]
sidereal_time = []
for i in (range(len(time_file))):
    sidereal_time.append(my_sidereal_time(time_file[i], delta))

# %%
mean_1 = where(sidereal_time, source)
point_time = [i for i in (range(number_of_points))]
mean_2 = point_time[(sidereal_time.index(mean_1)) * num]

time_file = [(time_start + dt * i)
        for i in range(mean_2 - int(num / 2), mean_2 + int(num / 2))]

sidereal_time = []
for i in (range(len(time_file))):
    sidereal_time.append(my_sidereal_time(time_file[i], delta))

mean_1 = where(sidereal_time, source)
mean_3 = (sidereal_time.index(mean_1))

if mean_3 <= (len(sidereal_time) / 2):
    MEAN = int(point_time[point_time.index(
        mean_2)] - len(sidereal_time) / 2 + mean_3)
else:
    MEAN = int(point_time[point_time.index(mean_2)] + abs(
        len(sidereal_time) / 2 - mean_3))

index = int(
    round(
        7 * 60 * 1000 / float(head['tresolution'][0]) / np.cos(math.radians(delta[0]
                                                      + delta[1] / 60 + delta[2] / 3600)) / 2))


index1 = MEAN - index
index2 = MEAN + index

my_mean = time_start + dt * MEAN

CONST1 = 0
CONST2 = 0

# %%
print(index)
# Out:
# 2814

# %%
if (number_of_points - MEAN) < index:

    data_32, time_start2, point_time = on_the_border(
        number_of_points, data, file, index1, index2, point_time, MEAN, reg, head)
    data_32.reverse()
    data_32_origin = copy(data_32)
    CONST1 += 1
    

else:
    if MEAN < index:
        data_32, time_start2, point_time = on_the_border_2(
            number_of_points, data, file, index1, index2, point_time, MEAN, reg, head)
        data_32.reverse()
        data_32_origin = copy(data_32)
        CONST2 += 1

    else:
        data_32 = [[
            data[q][module - 1][ray - 1][x] for q in range(number_of_points)
        ] for x in (range(int(head['nbands'][0])))]
        data_32.reverse()
        point_time = point_time[index1:index2]
        data_32_origin = copy(data_32)
        for i in (range(int(head['nbands'][0]))):
            data_32[i] = data_32[i][index1:index2]
# Out:
# Сшитый файл_2
# индекс  35836
# 5628

# %%
nbands = [] #обратные квадраты
for i in range(int(head['nbands'][0])):
    nbands.append((float((head['fbands'][i])[0:-1:]))**-2)

point_time_cut = point_time

b = head['time_begin'][0]
b2 = head['date_begin'][0]
date_format = "%d.%m.%Y %H:%M:%S"

hour,minute,seconds = b.split(':')
time_end = time(int(hour)+1,int(minute),0)
time_end = str(b2) + ' '+ str(b)
time_end = datetime.strptime(time_end, date_format)

# %%
n, t, t2 = [], [], []
for i in range(int(head['nbands'][0])):
    n.append((float((head['fbands'][i])[0:-1:]))**-2)

for i in range(int(head['nbands'][0])):
    t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM)))

for i in range(int(head['nbands'][0])):
    if t[i] == 0:
        t2.append(0)
    else:
        t2.append((round(t[i] / (float(head['tresolution'][0])/1000))))

data_32_wdm = copy(data_32)
for i in range(int(head['nbands'][0])):
    data_32[i] = data_32[i][t2[i]:] + data_32[i][:t2[i]]

# %%
print(t2)
# Out:
# [-32, -25, -19, -13, -6, 0]

# %%
q = len(data_32)
q2 = len(data_32[0])
summ = [0 for i in range(len(data_32[0]))]
summ_wdm = [0 for i in range(len(data_32[0]))]

# %%
for i in range(q):
    for k in range(q2):
        summ[k] += data_32[i][k]
        summ_wdm[k] += data_32_wdm[i][k]

# %%
dm_ind = 250
step_background = 25
summ_after_background = flatter(summ[dm_ind:], step_background)
summ_wdm_after_background = flatter(summ_wdm[dm_ind:], step_background)
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
# <img src="data:image/png;base64,..." width="799.5333333333333">
# <img src="data:image/png;base64,..." width="799.5333333333333">
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
len(summ_after_background)
# Out:
# 5350

# %%
650*0.1*1000/12.4928
# Out:
# 5202.996926229508

# %%
20*1000/12.4928
# Out:
# 1600.922131147541

# %%
dm_ind
# Out:
# 250

# %%
#i1,i2 = 450,800
#i1,i2 = 4300,i1+1600
#i1,i2 = 400,650
#i1,i2 = 50,300
#k = 1 #очень похоже
k = 9

i1,i2 = 0,400


n_dm_pic = summ_after_background[dm_ind+i1:i2]
n_wdm_pic = summ_wdm_after_background[dm_ind+i1:i2]

fig, ax = plt.subplots(figsize=(8, 6))
plt.title('all_channel', size=15)
ax.xaxis.set_major_locator(ticker.MultipleLocator(1000))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)

plt.plot(n_wdm_pic, label = 'DM = 0')
plt.plot(n_dm_pic,  label = 'DM = ' + str(round(DM*10**3)))

plt.ylabel('amplitude (acp)', size=15)
plt.xlabel('time (points)', size=15)
plt.legend()
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
def scattering_kuz (DM):
    t_s = 60*(DM/100)**2.2
    return t_s

def scatter (x,t_s, t):
    a = []
    for i in range(len(x)):
        if x[i] < 0:
            a.append(0)
        else:
            #a.append((1/t_s)*(np.exp(-x[i]/t_s)))
            a.append((np.exp(-x[i]/t_s)))
            
    return a

def pulse (x,a,b,s):
    c = []
    for i in range(len(x)):
        c.append(a*np.exp(-(((x[i] - b)**2)/(2*s**2))))
        
    return c

DM = 247
t_s = 0.275*1000

n, t, t2 = [], [], []
for i in range(int(head['nbands'][0])):
    n.append((float((head['fbands'][i])[0:-1:]))**-2)

for i in range(int(head['nbands'][0])):
    t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM*10**-3))) #в секундах 

for i in range(int(head['nbands'][0])):
    if t[i] == 0:
        t2.append(0)
    else:
        t2.append(abs(round(t[i] / (float(head['tresolution'][0])/1000)))) # в точках
        
t4 = [abs(i)*1000 for i in t]
t4.sort()
t2.sort()
t3 = [abs(i) for i in t]
t3.sort()


x = [i for i in range(-1,int(t_s*10))]
x_scatter = scatter(x,t_s,t4[1])

norm = 1/max(x_scatter)
for i in range (len((x_scatter))):
    x_scatter[i]*=norm

#plt.plot(time_plot[:int(t_s*11.5)],x_scatter[:int(t_s*11.5)], 'r')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.title('pattern', size=15)
#ax.xaxis.set_major_locator(ticker.MultipleLocator(int(len(x)/10)))
ax.tick_params(axis='both', which='major', labelsize=10, length = 5,    #  Длинна делений
           width = 1)

#time_plot = [i for i in range(len(x_scatter))]
time_plot = [i/1000 for i in x]

plt.plot(time_plot,x_scatter, 'r')
ax.grid(which='both', color='grey', linewidth=0.5, linestyle='--')
plt.grid(True)
plt.ylabel('amplitude(acp)', size=15)
plt.xlabel('time (s)', size=15)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
#i1,i2 = 4500,i1+1600
i1,i2 = 250,400
n = summ_after_background[i1:i2]
#n = summ_after_background
print(len(n))
norm = 1/max(n)
for i in range (len((n))):
    n[i]*=norm
    
#n = summ_after_background[12950:13250]
#n = flatter(n,35)
c = np.correlate(n, x_scatter)
# Out:
# 150

# %%
def scattering_kuz (DM):
    t_s = 60*(DM/100)**2.2
    return t_s

def scatter (x,t_s, t):
    a = []
    for i in range(len(x)):
        if x[i] < 0:
            a.append(0)
        else:
            #a.append((1/t_s)*(np.exp(-x[i]/t_s)))
            a.append((np.exp(-x[i]/t_s)))
            
    return a

def pulse (x,a,b,s):
    c = []
    for i in range(len(x)):
        c.append(a*np.exp(-(((x[i] - b)**2)/(2*s**2))))
        
    return c

DM = 247
t_s = 0.275*1000/100

n, t, t2 = [], [], []
for i in range(int(head['nbands'][0])):
    n.append((float((head['fbands'][i])[0:-1:]))**-2)

for i in range(int(head['nbands'][0])):
    t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM*10**-3))) #в секундах 

for i in range(int(head['nbands'][0])):
    if t[i] == 0:
        t2.append(0)
    else:
        t2.append(abs(round(t[i] / (float(head['tresolution'][0])/1000)))) # в точках
        
t4 = [abs(i)*1000 for i in t]
t4.sort()
t2.sort()
t3 = [abs(i) for i in t]
t3.sort()


x = [i for i in range(-1,int(30))]
x_scatter = scatter(x,t_s,t4[1])

norm = 1/max(x_scatter)
for i in range (len((x_scatter))):
    x_scatter[i]*=norm

#plt.plot(time_plot[:int(t_s*11.5)],x_scatter[:int(t_s*11.5)], 'r')

#i1,i2 = 4500,i1+1600
n = summ_after_background[i1:i2]
#n = summ_after_background
print(len(n))
norm = 1/max(n)
for i in range (len((n))):
    n[i]*=norm
    
#n = summ_after_background[12950:13250]
#n = flatter(n,35)
c = np.correlate(n, x_scatter)
# Out:
# 150

# %%
3*1000/100
# Out:
# 30.0

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.title('all_ch', size=15)
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)
plt.plot(n, 'green')
plt.plot(x,x_scatter, 'y')
plt.ylabel('amplitude (acp)', size=15)
plt.xlabel('time (points)', size=15)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
#i1,i2 = 400,i1+600
fig, ax = plt.subplots(figsize=(8, 6))
plt.title('corr(all_ch, pattern)', size=15)
ax.xaxis.set_major_locator(ticker.MultipleLocator(500))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)
#plt.plot(c[i1:i2], 'r')
plt.plot(c, 'r')

plt.ylabel('amplitude', size=15)
plt.xlabel('time (points)', size=15)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
#n = summ_after_background[i1:i2]
#i1,i2 = 400,i1+400

n = summ_after_background[i1:i2]
c = np.correlate(n, x_scatter)

fig, ax = plt.subplots(figsize=(8, 6))
plt.title('corr(all_ch, pattern) -> moving_average', size=15);
ax.xaxis.set_major_locator(ticker.MultipleLocator(500))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)

lines = []    
    
for i in range(7,9,2):
    c2 = moving_average(c,i)
    line1, = ax.plot(c2, lw=1.5, label = 'step: ' + str(i))
    lines.append(line1)
    
    
leg = ax.legend(fancybox=True, shadow=True)
lined = {}  # Will map legend lines to original lines.
for legline, origline in zip(leg.get_lines(), lines):
    legline.set_picker(True)  # Enable picking on the legend line.
    lined[legline] = origline


def on_pick(event):
    legline = event.artist
    origline = lined[legline]
    visible = not origline.get_visible()
    origline.set_visible(visible)
    legline.set_alpha(1.0 if visible else 0.2)
    fig.canvas.draw()
    
plt.ylabel('amplitude (acp)', size=12);
plt.xlabel('time (points)', size=12);

fig.canvas.mpl_connect('pick_event', on_pick)
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
# 9

# %%
step_moving_average = 7
corr_dm, corr_wdm = [], []
i1,i2 = 200,i1+200
for i in range(6):
    n2 = data_32_wdm[i][i1+dm_ind:i2+dm_ind]
    n2 = flatter(n2,step_background,False)
    c = np.correlate(n2, x_scatter_2)
    c2 = moving_average(c,step_moving_average)
    corr_wdm.append(c2)
    
    
    n2_dm = data_32[i][i1+dm_ind:i2+dm_ind]
    n2_dm = flatter(n2_dm,step_background,False)
    c_dm = np.correlate(n2_dm, x_scatter_2)
    c2_dm = moving_average(c_dm,step_moving_average)
    corr_dm.append(c2_dm)

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.title('six channels before subtraction', size=13);
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)

lines = []
for i in range(6):
    line1, = ax.plot(data_32_wdm[i][i1+dm_ind:i2], lw=1.5, label = str(i) + ' channel')    
    lines.append(line1)
    
    
leg = ax.legend(fancybox=True, shadow=True)
lined = {}  # Will map legend lines to original lines.
for legline, origline in zip(leg.get_lines(), lines):
    legline.set_picker(True)  # Enable picking on the legend line.
    lined[legline] = origline


def on_pick(event):
    legline = event.artist
    origline = lined[legline]
    visible = not origline.get_visible()
    origline.set_visible(visible)
    legline.set_alpha(1.0 if visible else 0.2)
    fig.canvas.draw()
    
plt.ylabel('amplitude (acp)', size=12);
plt.xlabel('time (points)', size=12);

fig.canvas.mpl_connect('pick_event', on_pick)
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
# 9

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.title('corr(all_ch, pattern)', size=13)
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)

lines = []
for i in range(6):
    line1, = ax.plot(corr_wdm[i], lw=1.5, label = str(i) + ' channel')
    lines.append(line1)
    
    
leg = ax.legend(fancybox=True, shadow=True)
lined = {}  # Will map legend lines to original lines.
for legline, origline in zip(leg.get_lines(), lines):
    legline.set_picker(True)  # Enable picking on the legend line.
    lined[legline] = origline


def on_pick(event):
    legline = event.artist
    origline = lined[legline]
    visible = not origline.get_visible()
    origline.set_visible(visible)
    legline.set_alpha(1.0 if visible else 0.2)
    fig.canvas.draw()
    
plt.ylabel('amplitude (acp)', size=12);
plt.xlabel('time (points)', size=12);

fig.canvas.mpl_connect('pick_event', on_pick)
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">
# 9

# %%
summ = [0 for i in range(len(corr_wdm[0]))]

q = len(corr_wdm)
q2 = len(corr_wdm[i])

for i in range(q):
    for k in range(q2):
        summ[k] += corr_wdm[i][k]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.title('corr(all_ch, pattern)', size=15)
ax.xaxis.set_major_locator(ticker.MultipleLocator(500))
ax.tick_params(axis='both', which='major', labelsize=10, length = 10,    #  Длинна делений
           width = 1.5)
plt.plot(summ, 'r')
plt.ylabel('amplitude', size=15)
plt.xlabel('time (points)', size=15)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
fbands = [round(float(head['fbands'][i]),2) for i in range(len(head['fbands']))]
fbands.reverse()
fig, ax = plt.subplots(figsize=(15, 2))
plt.xlabel('Время [мс]', fontsize=12)
sns.axes_style('whitegrid')
plt.ylabel("Плотность потока [АЦП]", fontsize=12)
heatmap_plot = sns.heatmap(corr_dm,
                           cmap="Greys", yticklabels=False)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="1499.6833333333334">

# %%
corr_aver_dm = []
for i in range(6):
    b = normalize(corr_dm[i])
    #a = averaging(b, 1)
    corr_aver_dm.append(b)

fig, ax = plt.subplots(figsize=(15, 2))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1000))
plt.xlabel('Время [мс]', fontsize=12)
sns.axes_style('whitegrid')
x_labels = [i for i in range(0,len(corr_aver_dm[0]),100)]
plt.ylabel("Плотность потока [АЦП]", fontsize=12)
heatmap_plot = sns.heatmap(corr_aver_dm,
                           cmap="Greys", yticklabels=False)
plt.show();

# %%
from scipy.ndimage.filters import gaussian_filter
corr_blur_dm = []
for i in range(len(corr_dm)):
    a = gaussian_filter(corr_dm[i], sigma=5)
    a = normalize(a)
    corr_blur_dm.append(a)

# %%
fig, ax = plt.subplots(figsize=(15, 2))
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.xlabel('Время [мс]', fontsize=12)
sns.axes_style('whitegrid')
x_labels = [i for i in range(0,len(corr_aver_dm[0]),100)]
plt.ylabel("Плотность потока [АЦП]", fontsize=12)
heatmap_plot = sns.heatmap(corr_blur_dm,
                           cmap="Greys", yticklabels=False)

plt.show();

# %%
fig, ax = plt.subplots(figsize=(15, 2))
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.xlabel('Время [мс]', fontsize=12)
sns.axes_style('whitegrid')
x_labels = [i for i in range(0,len(corr_aver_dm[0]),100)]
plt.ylabel("Плотность потока [АЦП]", fontsize=12)
heatmap_plot = sns.heatmap(corr_wdm,
                           cmap="Greys", yticklabels=False)

plt.show();

# %%
corr_aver_wdm = []
for i in range(6):
    b = normalize(corr_wdm[i])
    #a = averaging(b, 1)
    corr_aver_wdm.append(b)

fig, ax = plt.subplots(figsize=(15, 2))
ax.xaxis.set_major_locator(ticker.MultipleLocator(1000))
plt.xlabel('Время [мс]', fontsize=12)
sns.axes_style('whitegrid')
x_labels = [i for i in range(0,len(corr_aver_wdm[0]),100)]
plt.ylabel("Плотность потока [АЦП]", fontsize=12)
heatmap_plot = sns.heatmap(corr_aver_wdm,
                           cmap="Greys", yticklabels=fbands, cbar=False)
plt.show();

# %%
from scipy.ndimage.filters import gaussian_filter
corr_blur_wdm = []
for i in range(len(corr_wdm)):
    a = gaussian_filter(corr_wdm[i], sigma=5)
    a = normalize(a)
    corr_blur_wdm.append(a)

# %%
fig, ax = plt.subplots(figsize=(15, 2))
ax.xaxis.set_major_locator(ticker.MultipleLocator(100))
plt.xlabel('Время [мс]', fontsize=12)
sns.axes_style('whitegrid')
x_labels = [i for i in range(0,len(corr_aver_wdm[0]),100)]
plt.ylabel("Плотность потока [АЦП]", fontsize=12)
heatmap_plot = sns.heatmap(corr_blur_wdm,
                           cmap="Greys", yticklabels=fbands)

plt.show();

# %% [markdown]
# ## Шаблоны импульса с учетом рассеяния в зависимости от DM по Кузьмину

# %%
def scattering_kuz (DM):
    t_s = 60*(DM/100)**2.2
    return t_s

def scatter (x,t_s, t):
    a = []
    for i in range(len(x)):
        if x[i] < 0:
            a.append(0)
        else:
            #a.append((1/t_s)*(np.exp(-x[i]/t_s)))
            a.append((np.exp(-x[i]/t_s)))
            
    return a

def pulse (x,a,b,s):
    c = []
    for i in range(len(x)):
        c.append(a*np.exp(-(((x[i] - b)**2)/(2*s**2))))
        
    return c

# %%
t_s_list = []
dm_list = [i for i in range(3,2005)]
for i in range(len(dm_list)):
    DM = dm_list[i]
    t_s = scattering_kuz (DM)
    t_s_list.append(t_s)    
    print(DM, t_s)
# Out:
# 3 0.02678045866062927
# 4 0.0504293338445523
# 5 0.08239204074795879
# 6 0.12305067523812377
# 7 0.17272966805591164
# 8 0.23171237132333417
# 9 0.30025121337576205
# 10 0.3785744066881158
# 11 0.4668906295090626
# 12 0.5653924329092288
# 13 0.6742588033526856
# 14 0.7936571422200385
# 15 0.9237448290401523
# 16 1.0646704790863046
# 17 1.2165749712277873
# 18 1.3795922995624066
# 19 1.5538502875001667
# 20 1.739471192826469
# 21 1.9365722251809045
# 22 2.1452659923223614
# 23 2.3656608878650465
# 24 2.5978614304424106
# 25 2.8419685622069957
# 26 3.0980799130139975
# 27 3.3662900354335865
# 28 3.646690614799225
# 29 3.9393706577605303
# 30 4.244416662221762
# 31 4.561912771075677
# 32 4.891940911761374
# 33 5.234580923364046
# 34 5.589910672719699
# 35 5.958006160777274
# 36 6.338941620295654
# 37 6.732789605806682
# 38 7.139621076652447
# 39 7.559505473801181
# 40 7.992510791057981
# 41 8.438703641211461
# 42 8.898149317593013
# 43 9.37091185147008
# 44 9.857054065647116
# 45 10.356637624606483
# 46 10.869723081485617
# 47 11.396369922155476
# 48 11.936636606637768
# 49 12.490580608074461
# 50 13.05825844944186
# 51 13.639725738182815
# 52 14.235037198914146
# 53 14.844246704351635
# 54 15.467407304581887
# 55 16.10457125479882
# 56 16.755790041611984
# 57 17.42111440802482
# 58 18.10059437717244
# 59 18.794279274901054
# 60 19.502217751264578
# 61 20.22445780100757
# 62 20.961046783098386
# 63 21.7120314393713
# 64 22.477457912331946
# 65 23.257371762176128
# 66 24.051817983068567
# 67 24.860841018724475
# 68 25.684484777333953
# 69 26.522792645866225
# 70 27.375807503788224
# 71 28.24357173622948
# 72 29.12612724662343
# 73 30.02351546885277
# 74 30.93577737892509
# 75 31.862953506202942
# 76 32.805083944211304
# 77 33.76220836104355
# 78 34.734366009385994
# 79 35.72159573617974
# 80 36.723935991937424
# 81 37.74142483973132
# 82 38.77409996386839
# 83 39.82199867826691
# 84 40.88515793454834
# 85 41.96361432985756
# 86 43.057404114423605
# 87 44.16656319887243
# 88 45.291127161302725
# 89 46.43113125413495
# 90 47.586610410743475
# 91 48.757599251880876
# 92 49.94413209190333
# 93 51.146242944805195
# 94 52.36396553007073
# 95 53.597333278350426
# 96 54.84637933696878
# 97 56.111136575270635
# 98 57.39163758981201
# 99 58.68791470940181
# 100 60.0
# 101 61.327925269477845
# 102 62.67172207224528
# 103 64.03142171375063
# 104 65.40705525485714
# 105 66.79865351610106
# 106 68.20624708183553
# 107 69.6298663042643
# 108 71.06954130736935
# 109 72.52530199073611
# 110 73.99717803327977
# 111 75.48519889687634
# 112 76.98939382990156
# 113 78.50979187068077
# 114 80.04642185085304
# 115 81.59931239865193
# 116 83.16849194210626
# 117 84.75398871216291
# 118 86.35583074573483
# 119 87.97404588867603
# 120 89.60866179868638
# 121 91.25970594814831
# 122 92.9272056268974
# 123 94.6111879449292
# 124 96.31167983504403
# 125 98.02870805543186
# 126 99.76229919219888
# 127 101.51247966183777
# 128 103.27927571364317
# 129 105.06271343207412
# 130 106.86281873906485
# 131 108.67961739628582
# 132 110.51313500735587
# 133 112.36339702000757
# 134 114.23042872820648
# 135 116.11425527422611
# 136 118.01490165067962
# 137 119.93239270250942
# 138 121.86675312893598
# 139 123.81800748536709
# 140 125.78618018526808
# 141 127.77129550199487
# 142 129.77337757059024
# 143 131.79245038954474
# 144 133.82853782252263
# 145 135.88166360005454
# 146 137.9518513211969
# 147 140.03912445515968
# 148 142.14350634290295
# 149 144.26502019870307
# 150 146.40368911168932
# 151 148.55953604735168
# 152 150.7325838490207
# 153 152.92285523931994
# 154 155.1303728215915
# 155 157.35515908129597
# 156 159.5972363873865
# 157 161.85662699365855
# 158 164.1333530400751
# 159 166.4274365540686
# 160 168.73889945181972
# 161 171.06776353951363
# 162 173.41405051457443
# 163 175.77778196687814
# 164 178.15897937994487
# 165 180.55766413211023
# 166 182.97385749767722
# 167 185.40758064804828
# 168 187.85885465283863
# 169 190.32770048097046
# 170 192.81413900174957
# 171 195.31819098592374
# 172 197.83987710672386
# 173 200.3792179408881
# 174 202.93623396966942
# 175 205.5109455798266
# 176 208.1033730645999
# 177 210.71353662467044
# 178 213.34145636910498
# 179 215.98715231628526
# 180 218.65064439482325
# 181 221.3319524444617
# 182 224.03109621696095
# 183 226.74809537697195
# 184 229.48296950289597
# 185 232.23573808773105
# 186 235.00642053990578
# 187 237.79503618410024
# 188 240.60160426205482
# 189 243.426143933367
# 190 246.2686742762759
# 191 249.12921428843578
# 192 252.00778288767765
# 193 254.90439891276023
# 194 257.8190811241094
# 195 260.75184820454757
# 196 263.70271876001226
# 197 266.67171132026385
# 198 269.6588443395846
# 199 272.6641361974661
# 200 275.68760519928844
# 201 278.72926957698866
# 202 281.78914748972124
# 203 284.8672570245074
# 204 287.96361619687815
# 205 291.07824295150533
# 206 294.21115516282714
# 207 297.3623706356623
# 208 300.5319071058183
# 209 303.7197822406895
# 210 306.92601363984886
# 211 310.15061883562987
# 212 313.3936152937032
# 213 316.65502041364283
# 214 319.93485152948756
# 215 323.23312591029253
# 216 326.5498607606761
# 217 329.88507322135695
# 218 333.23878036968705
# 219 336.61099922017496
# 220 340.00174672500486
# 221 343.41103977454696
# 222 346.83889519786345
# 223 350.2853297632056
# 224 353.75036017850726
# 225 357.2340030918696
# 226 360.7362750920424
# 227 364.257192708897
# 228 367.7967724138945
# 229 371.35503062054886
# 230 374.9319836848826
# 231 378.527647905879
# 232 382.14203952592646
# 233 385.7751747312601
# 234 389.42706965239535
# 235 393.0977403645588
# 236 396.787202888112
# 237 400.4954731889717
# 238 404.2225671790234
# 239 407.9685007165323
# 240 411.7332896065469
# 241 415.5169496013003
# 242 419.31949640060446
# 243 423.1409456522424
# 244 426.98131295235316
# 245 430.840613845815
# 246 434.718863826622
# 247 438.61607833825803
# 248 442.53227277406484
# 249 446.46746247760814
# 250 450.4216627430368
# 251 454.3948888154409
# 252 458.38715589120363
# 253 462.39847911834994
# 254 466.4288735968922
# 255 470.4783543791699
# 256 474.54693647018865
# 257 478.63463482795225
# 258 482.7414643637938
# 259 486.867439942701
# 260 491.0125763836405
# 261 495.1768884598754
# 262 499.36039089928266
# 263 503.5630983846648
# 264 507.78502555405976
# 265 512.0261870010459
# 266 516.2865972750458
# 267 520.5662708816245
# 268 524.8652222827874
# 269 529.1834658972714
# 270 533.5210161008374
# 271 537.8778872265553
# 272 542.2540935650903
# 273 546.6496493649818
# 274 551.064568832924
# 275 555.4988661340396
# 276 559.9525553921542
# 277 564.4256506900648
# 278 568.9181660698071
# 279 573.4301155329214
# 280 577.9615130407125
# 281 582.5123725145105
# 282 587.0827078359264
# 283 591.6725328471067
# 284 596.2818613509846
# 285 600.9107071115297
# 286 605.5590838539936
# 287 610.2270052651551
# 288 614.914484993561
# 289 619.6215366497669
# 290 624.3481738065726
# 291 629.0944099992587
# 292 633.8602587258176
# 293 638.6457334471854
# 294 643.4508475874679
# 295 648.2756145341692
# 296 653.120047638413
# 297 657.9841602151663
# 298 662.8679655434571
# 299 667.7714768665941
# 300 672.6947073923795
# 301 677.6376702933251
# 302 682.6003787068624
# 303 687.5828457355518
# 304 692.5850844472911
# 305 697.6071078755202
# 306 702.6489290194262
# 307 707.7105608441435
# 308 712.7920162809557
# 309 717.8933082274922
# 310 723.0144495479258
# 311 728.1554530731664
# 312 733.3163316010553
# 313 738.4970978965542
# 314 743.6977646919371
# 315 748.9183446869756
# 316 754.1588505491275
# 317 759.4192949137185
# 318 764.6996903841282
# 319 770.0000495319674
# 320 775.3203848972618
# 321 780.6607089886262
# 322 786.0210342834444
# 323 791.401373228041
# 324 796.8017382378576
# 325 802.2221416976223
# 326 807.6625959615217
# 327 813.1231133533696
# 328 818.6037061667735
# 329 824.1043866653022
# 330 829.6251670826488
# 331 835.1660596227958
# 332 840.727076460175
# 333 846.3082297398298
# 334 851.9095315775728
# 335 857.5309940601452
# 336 863.1726292453714
# 337 868.8344491623162
# 338 874.5164658114368
# 339 880.2186911647372
# 340 885.9411371659177
# 341 891.6838157305272
# 342 897.4467387461093
# 343 903.2299180723534
# 344 909.0333655412372
# 345 914.8570929571757
# 346 920.7011120971623
# 347 926.5654347109139
# 348 932.4500725210107
# 349 938.355037223039
# 350 944.2803404857282
# 351 950.225993951091
# 352 956.1920092345608
# 353 962.1783979251256
# 354 968.1851715854658
# 355 974.2123417520863
# 356 980.2599199354505
# 357 986.3279176201115
# 358 992.4163462648438
# 359 998.5252173027719
# 360 1004.6545421415008
# 361 1010.8043321632415
# 362 1016.9745987249407
# 363 1023.1653531584038
# 364 1029.376606770422
# 365 1035.6083708428948
# 366 1041.860656632954
# 367 1048.1334753730841
# 368 1054.4268382712455
# 369 1060.740756510993
# 370 1067.0752412515958
# 371 1073.4303036281558
# 372 1079.8059547517248
# 373 1086.2022057094212
# 374 1092.6190675645455
# 375 1099.0565513566958
# 376 1105.51466810188
# 377 1111.9934287926321
# 378 1118.4928443981205
# 379 1125.0129258642633
# 380 1131.553684113835
# 381 1138.1151300465808
# 382 1144.6972745393202
# 383 1151.3001284460609
# 384 1157.9237025981013
# 385 1164.568007804141
# 386 1171.2330548503828
# 387 1177.918854500642
# 388 1184.6254174964465
# 389 1191.3527545571442
# 390 1198.1008763800019
# 391 1204.8697936403114
# 392 1211.6595169914874
# 393 1218.4700570651705
# 394 1225.3014244713256
# 395 1232.1536297983416
# 396 1239.0266836131298
# 397 1245.9205964612222
# 398 1252.8353788668678
# 399 1259.7710413331292
# 400 1266.7275943419788
# 401 1273.7050483543933
# 402 1280.7034138104482
# 403 1287.7227011294124
# 404 1294.7629207098385
# 405 1301.8240829296597
# 406 1308.9061981462771
# 407 1316.0092766966548
# 408 1323.133328897406
# 409 1330.2783650448876
# 410 1337.4443954152862
# 411 1344.6314302647088
# 412 1351.839479829268
# 413 1359.0685543251736
# 414 1366.3186639488158
# 415 1373.5898188768545
# 416 1380.882029266301
# 417 1388.1953052546082
# 418 1395.5296569597508
# 419 1402.8850944803132
# 420 1410.2616278955675
# 421 1417.6592672655627
# 422 1425.0780226312022
# 423 1432.5179040143287
# 424 1439.9789214178022
# 425 1447.4610848255843
# 426 1454.9644042028167
# 427 1462.488889495899
# 428 1470.034550632572
# 429 1477.6013975219917
# 430 1485.1894400548103
# 431 1492.7986881032539
# 432 1500.4291515211978
# 433 1508.080840144244
# 434 1515.753763789797
# 435 1523.4479322571403
# 436 1531.1633553275112
# 437 1538.9000427641731
# 438 1546.658004312493
# 439 1554.4372497000134
# 440 1562.2377886365266
# 441 1570.0596308141444
# 442 1577.9027859073742
# 443 1585.767263573189
# 444 1593.6530734510993
# 445 1601.5602251632217
# 446 1609.488728314353
# 447 1617.438592492038
# 448 1625.40982726664
# 449 1633.4024421914069
# 450 1641.4164468025458
# 451 1649.4518506192856
# 452 1657.508663143948
# 453 1665.5868938620151
# 454 1673.686552242192
# 455 1681.8076477364798
# 456 1689.950189780238
# 457 1698.114187792251
# 458 1706.2996511747924
# 459 1714.506589313692
# 460 1722.7350115783995
# 461 1730.984927322049
# 462 1739.2563458815205
# 463 1747.549276577507
# 464 1755.863728714575
# 465 1764.1997115812287
# 466 1772.5572344499692
# 467 1780.9363065773607
# 468 1789.3369372040893
# 469 1797.7591355550253
# 470 1806.2029108392812
# 471 1814.668272250277
# 472 1823.1552289657964
# 473 1831.6637901480483
# 474 1840.1939649437238
# 475 1848.745762484059
# 476 1857.3191918848909
# 477 1865.9142622467157
# 478 1874.5309826547496
# 479 1883.169362178981
# 480 1891.829409874233
# 481 1900.5111347802192
# 482 1909.2145459215985
# 483 1917.939652308031
# 484 1926.686462934238
# 485 1935.4549867800538
# 486 1944.245232810483
# 487 1953.057209975752
# 488 1961.8909272113692
# 489 1970.746393438176
# 490 1979.6236175624022
# 491 1988.5226084757162
# 492 1997.4433750552835
# 493 2006.3859261638165
# 494 2015.3502706496308
# 495 2024.3364173466907
# 496 2033.3443750746703
# 497 2042.3741526389983
# 498 2051.4257588309156
# 499 2060.49920242752
# 500 2069.594492191823
# 501 2078.7116368727975
# 502 2087.8506452054307
# 503 2097.011525910771
# 504 2106.1942876959806
# 505 2115.398939254384
# 506 2124.625489265518
# 507 2133.8739463951815
# 508 2143.1443192954803
# 509 2152.4366166048817
# 510 2161.750846948258
# 511 2171.0870189369393
# 512 2180.4451411687533
# 513 2189.825222228081
# 514 2199.227270685901
# 515 2208.6512950998367
# 516 2218.097304014199
# 517 2227.56530596004
# 518 2237.0553094551938
# 519 2246.5673230043267
# 520 2256.1013550989755
# 521 2265.6574142176037
# 522 2275.2355088256368
# 523 2284.835647375515
# 524 2294.45783830673
# 525 2304.102090045878
# 526 2313.7684110066984
# 527 2323.45680959012
# 528 2333.1672941843035
# 529 2342.8998731646852
# 530 2352.654554894023
# 531 2362.431347722435
# 532 2372.230259987448
# 533 2382.0513000140318
# 534 2391.8944761146527
# 535 2401.759796589306
# 536 2411.647269725564
# 537 2421.5569037986133
# 538 2431.488707071301
# 539 2441.4426877941723
# 540 2451.4188542055144
# 541 2461.4172145313933
# 542 2471.4377769857
# 543 2481.480549770187
# 544 2491.5455410745103
# 545 2501.632759076268
# 546 2511.742211941042
# 547 2521.8739078224376
# 548 2532.027854862121
# 549 2542.2040611898583
# 550 2552.4025349235585
# 551 2562.623284169309
# 552 2572.8663170214154
# 553 2583.1316415624387
# 554 2593.419265863234
# 555 2603.729197982992
# 556 2614.0614459692697
# 557 2624.416017858038
# 558 2634.792921673706
# 559 2645.1921654291737
# 560 2655.6137571258555
# 561 2666.0577047537267
# 562 2676.5240162913537
# 563 2687.012699705934
# 564 2697.523762953334
# 565 2708.0572139781216
# 566 2718.6130607136024
# 567 2729.1913110818596
# 568 2739.791972993785
# 569 2750.4150543491182
# 570 2761.0605630364776
# 571 2771.728506933401
# 572 2782.4188939063765
# 573 2793.1317318108795
# 574 2803.8670284914033
# 575 2814.6247917815
# 576 2825.4050295038105
# 577 2836.2077494700993
# 578 2847.0329594812897
# 579 2857.8806673274935
# 580 2868.7508807880517
# 581 2879.643607631562
# 582 2890.5588556159155
# 583 2901.4966324883258
# 584 2912.4569459853674
# 585 2923.439803833005
# 586 2934.4452137466274
# 587 2945.4731834310774
# 588 2956.5237205806893
# 589 2967.5968328793174
# 590 2978.692528000369
# 591 2989.8108136068336
# 592 3000.951697351321
# 593 3012.115186876087
# 594 3023.3012898130683
# 595 3034.5100137839104
# 596 3045.7413664000023
# 597 3056.995355262506
# 598 3068.271987962389
# 599 3079.571272080449
# 600 3090.893215187353
# 601 3102.2378248436617
# 602 3113.605108599864
# 603 3124.995073996402
# 604 3136.407728563705
# 605 3147.843079822218
# 606 3159.301135282434
# 607 3170.7819024449195
# 608 3182.2853888003438
# 609 3193.811601829513
# 610 3205.360549003397
# 611 3216.9322377831572
# 612 3228.5266756201736
# 613 3240.14386995608
# 614 3251.783828222787
# 615 3263.4465578425147
# 616 3275.132066227815
# 617 3286.8403607816063
# 618 3298.571448897199
# 619 3310.325337958324
# 620 3322.102035339157
# 621 3333.901548404353
# 622 3345.7238845090687
# 623 3357.5690509989927
# 624 3369.43705521037
# 625 3381.327904470033
# 626 3393.2416060954247
# 627 3405.1781673946307
# 628 3417.137595666401
# 629 3429.119898200178
# 630 3441.125082276126
# 631 3453.1531551651556
# 632 3465.2041241289503
# 633 3477.2779964199913
# 634 3489.3747792815875
# 635 3501.4944799478976
# 636 3513.6371056439602
# 637 3525.802663585713
# 638 3537.991160980026
# 639 3550.2026050247237
# 640 3562.4370029086103
# 641 3574.6943618114947
# 642 3586.9746889042162
# 643 3599.277991348673
# 644 3611.6042762978427
# 645 3623.9535508958074
# 646 3636.3258222777813
# 647 3648.721097570136
# 648 3661.1393838904214
# 649 3673.58068834739
# 650 3686.0450180410285
# 651 3698.532380062574
# 652 3711.0427814945397
# 653 3723.5762294107467
# 654 3736.1327308763334
# 655 3748.712292947795
# 656 3761.314922672996
# 657 3773.940627091202
# 658 3786.5894132330927
# 659 3799.2612881207992
# 660 3811.956258767916
# 661 3824.674332179532
# 662 3837.4155153522456
# 663 3850.179815274195
# 664 3862.967238925078
# 665 3875.777793276179
# 666 3888.6114852903816
# 667 3901.4683219222034
# 668 3914.348310117811
# 669 3927.2514568150464
# 670 3940.177768943445
# 671 3953.1272534242617
# 672 3966.0999171704952
# 673 3979.0957670869043
# 674 3992.1148100700307
# 675 4005.157053008227
# 676 4018.2225027816735
# 677 4031.3111662623987
# 678 4044.4230503143076
# 679 4057.558161793194
# 680 4070.7165075467688
# 681 4083.8980944146833
# 682 4097.102929228543
# 683 4110.331018811933
# 684 4123.582369980439
# 685 4136.8569895416695
# 686 4150.154884295277
# 687 4163.47606103297
# 688 4176.820526538551
# 689 4190.18828758792
# 690 4203.5793509491095
# 691 4216.99372338229
# 692 4230.4314116398045
# 693 4243.892422466181
# 694 4257.376762598158
# 695 4270.884438764695
# 696 4284.415457687004
# 697 4297.969826078565
# 698 4311.547550645146
# 699 4325.148638084818
# 700 4338.773095087985
# 701 4352.420928337395
# 702 4366.092144508164
# 703 4379.786750267796
# 704 4393.5047522762
# 705 4407.2461571857075
# 706 4421.010971641098
# 707 4434.799202279617
# 708 4448.610855730987
# 709 4462.445938617439
# 710 4476.304457553724
# 711 4490.186419147131
# 712 4504.091829997509
# 713 4518.020696697289
# 714 4531.973025831493
# 715 4545.948823977766
# 716 4559.948097706376
# 717 4573.9708535802565
# 718 4588.0170981550045
# 719 4602.08683797891
# 720 4616.180079592966
# 721 4630.2968295308965
# 722 4644.437094319169
# 723 4658.600880477014
# 724 4672.788194516437
# 725 4686.9990429422505
# 726 4701.2334322520755
# 727 4715.491368936374
# 728 4729.772859478456
# 729 4744.077910354498
# 730 4758.406528033572
# 731 4772.758718977648
# 732 4787.134489641621
# 733 4801.533846473323
# 734 4815.956795913548
# 735 4830.40334439606
# 736 4844.873498347618
# 737 4859.367264187985
# 738 4873.884648329952
# 739 4888.425657179356
# 740 4902.990297135091
# 741 4917.5785745891235
# 742 4932.190495926522
# 743 4946.826067525459
# 744 4961.4852957572375
# 745 4976.1681869863
# 746 4990.874747570253
# 747 5005.604983859878
# 748 5020.358902199152
# 749 5035.136508925256
# 750 5049.937810368602
# 751 5064.762812852844
# 752 5079.611522694892
# 753 5094.483946204931
# 754 5109.380089686438
# 755 5124.299959436193
# 756 5139.243561744304
# 757 5154.210902894216
# 758 5169.201989162723
# 759 5184.216826819997
# 760 5199.255422129589
# 761 5214.317781348459
# 762 5229.403910726976
# 763 5244.5138165089475
# 764 5259.647504931627
# 765 5274.8049822257335
# 766 5289.986254615461
# 767 5305.191328318503
# 768 5320.4202095460605
# 769 5335.67290450286
# 770 5350.949419387163
# 771 5366.249760390796
# 772 5381.573933699147
# 773 5396.921945491196
# 774 5412.293801939518
# 775 5427.689509210303
# 776 5443.109073463376
# 777 5458.552500852203
# 778 5474.019797523912
# 779 5489.5109696192985
# 780 5505.026023272857
# 781 5520.564964612777
# 782 5536.127799760971
# 783 5551.7145348330805
# 784 5567.325175938496
# 785 5582.959729180366
# 786 5598.61820065562
# 787 5614.300596454971
# 788 5630.006922662942
# 789 5645.737185357869
# 790 5661.491390611923
# 791 5677.26954449112
# 792 5693.071653055335
# 793 5708.897722358323
# 794 5724.747758447723
# 795 5740.6217673650735
# 796 5756.519755145832
# 797 5772.441727819388
# 798 5788.387691409071
# 799 5804.357651932165
# 800 5820.351615399931
# 801 5836.3695878176095
# 802 5852.411575184442
# 803 5868.477583493679
# 804 5884.567618732596
# 805 5900.681686882509
# 806 5916.8197939187785
# 807 5932.981945810837
# 808 5949.1681485221925
# 809 5965.378408010445
# 810 5981.612730227295
# 811 5997.8711211185655
# 812 6014.1535866242075
# 813 6030.460132678317
# 814 6046.790765209142
# 815 6063.1454901391035
# 816 6079.524313384806
# 817 6095.927240857046
# 818 6112.354278460831
# 819 6128.805432095387
# 820 6145.280707654173
# 821 6161.7801110249
# 822 6178.303648089526
# 823 6194.851324724289
# 824 6211.4231467997115
# 825 6228.019120180607
# 826 6244.639250726102
# 827 6261.283544289642
# 828 6277.952006719006
# 829 6294.644643856321
# 830 6311.361461538072
# 831 6328.10246559511
# 832 6344.8676618526715
# 833 6361.657056130389
# 834 6378.470654242302
# 835 6395.308461996866
# 836 6412.170485196971
# 837 6429.056729639947
# 838 6445.967201117584
# 839 6462.901905416129
# 840 6479.860848316318
# 841 6496.844035593372
# 842 6513.851473017015
# 843 6530.883166351489
# 844 6547.939121355557
# 845 6565.019343782523
# 846 6582.12383938024
# 847 6599.252613891115
# 848 6616.405673052138
# 849 6633.583022594875
# 850 6650.784668245491
# 851 6668.010615724759
# 852 6685.260870748067
# 853 6702.535439025433
# 854 6719.834326261519
# 855 6737.15753815564
# 856 6754.5050804017665
# 857 6771.876958688549
# 858 6789.273178699328
# 859 6806.693746112135
# 860 6824.138666599713
# 861 6841.6079458295235
# 862 6859.101589463759
# 863 6876.6196031593545
# 864 6894.16199256799
# 865 6911.728763336116
# 866 6929.31992110496
# 867 6946.935471510525
# 868 6964.575420183617
# 869 6982.239772749848
# 870 6999.928534829647
# 871 7017.641712038271
# 872 7035.379309985812
# 873 7053.141334277217
# 874 7070.92779051229
# 875 7088.7386842857095
# 876 7106.574021187032
# 877 7124.433806800706
# 878 7142.318046706084
# 879 7160.22674647743
# 880 7178.159911683936
# 881 7196.117547889717
# 882 7214.099660653839
# 883 7232.106255530325
# 884 7250.137338068158
# 885 7268.192913811297
# 886 7286.272988298688
# 887 7304.377567064269
# 888 7322.506655636988
# 889 7340.660259540801
# 890 7358.838384294696
# 891 7377.041035412696
# 892 7395.2682184038695
# 893 7413.51993877234
# 894 7431.796202017295
# 895 7450.097013633003
# 896 7468.422379108817
# 897 7486.772303929177
# 898 7505.146793573636
# 899 7523.545853516864
# 900 7541.969489228652
# 901 7560.417706173925
# 902 7578.890509812755
# 903 7597.387905600368
# 904 7615.909898987153
# 905 7634.456495418674
# 906 7653.027700335672
# 907 7671.623519174087
# 908 7690.243957365061
# 909 7708.889020334944
# 910 7727.55871350531
# 911 7746.253042292964
# 912 7764.972012109947
# 913 7783.715628363557
# 914 7802.483896456341
# 915 7821.27682178612
# 916 7840.094409745995
# 917 7858.936665724348
# 918 7877.803595104861
# 919 7896.6952032665195
# 920 7915.611495583624
# 921 7934.552477425801
# 922 7953.5181541580005
# 923 7972.508531140527
# 924 7991.523613729029
# 925 8010.563407274515
# 926 8029.627917123365
# 927 8048.717148617336
# 928 8067.8311070935715
# 929 8086.969797884611
# 930 8106.133226318405
# 931 8125.321397718305
# 932 8144.534317403094
# 933 8163.771990686987
# 934 8183.034422879638
# 935 8202.32161928615
# 936 8221.633585207082
# 937 8240.970325938464
# 938 8260.331846771798
# 939 8279.718152994068
# 940 8299.129249887756
# 941 8318.565142730842
# 942 8338.02583679682
# 943 8357.5113373547
# 944 8377.021649669014
# 945 8396.556778999837
# 946 8416.116730602791
# 947 8435.701509729037
# 948 8455.31112162531
# 949 8474.945571533908
# 950 8494.604864692712
# 951 8514.289006335184
# 952 8533.998001690386
# 953 8553.731855982978
# 954 8573.490574433235
# 955 8593.274162257054
# 956 8613.082624665947
# 957 8632.915966867076
# 958 8652.774194063246
# 959 8672.657311452906
# 960 8692.565324230174
# 961 8712.498237584832
# 962 8732.456056702345
# 963 8752.438786763858
# 964 8772.446432946206
# 965 8792.47900042193
# 966 8812.536494359283
# 967 8832.61891992223
# 968 8852.726282270463
# 969 8872.858586559405
# 970 8893.015837940226
# 971 8913.198041559841
# 972 8933.405202560918
# 973 8953.637326081895
# 974 8973.89441725698
# 975 8994.176481216167
# 976 9014.483523085231
# 977 9034.815547985747
# 978 9055.172561035091
# 979 9075.554567346453
# 980 9095.961572028846
# 981 9116.393580187094
# 982 9136.850596921873
# 983 9157.332627329695
# 984 9177.83967650292
# 985 9198.371749529764
# 986 9218.928851494316
# 987 9239.51098747653
# 988 9260.118162552242
# 989 9280.750381793172
# 990 9301.407650266941
# 991 9322.089973037071
# 992 9342.797355162991
# 993 9363.529801700051
# 994 9384.287317699524
# 995 9405.069908208614
# 996 9425.87757827047
# 997 9446.710332924176
# 998 9467.56817720478
# 999 9488.451116143293
# 1000 9509.359154766686
# 1001 9530.292298097911
# 1002 9551.250551155907
# 1003 9572.233918955597
# 1004 9593.242406507905
# 1005 9614.276018819763
# 1006 9635.334760894102
# 1007 9656.418637729887
# 1008 9677.5276543221
# 1009 9698.661815661764
# 1010 9719.821126735937
# 1011 9741.005592527723
# 1012 9762.215218016287
# 1013 9783.450008176853
# 1014 9804.709967980707
# 1015 9825.995102395218
# 1016 9847.305416383837
# 1017 9868.640914906102
# 1018 9890.001602917646
# 1019 9911.387485370213
# 1020 9932.798567211647
# 1021 9954.234853385922
# 1022 9975.696348833117
# 1023 9997.183058489456
# 1024 10018.6949872873
# 1025 10040.232140155147
# 1026 10061.794522017655
# 1027 10083.382137795634
# 1028 10104.994992406058
# 1029 10126.633090762074
# 1030 10148.296437773015
# 1031 10169.98503834438
# 1032 10191.698897377875
# 1033 10213.438019771402
# 1034 10235.20241041906
# 1035 10256.992074211168
# 1036 10278.807016034258
# 1037 10300.64724077109
# 1038 10322.512753300653
# 1039 10344.403558498165
# 1040 10366.319661235102
# 1041 10388.261066379184
# 1042 10410.22777879439
# 1043 10432.21980334096
# 1044 10454.237144875404
# 1045 10476.279808250512
# 1046 10498.347798315359
# 1047 10520.441119915293
# 1048 10542.559777891976
# 1049 10564.703777083363
# 1050 10586.873122323723
# 1051 10609.067818443633
# 1052 10631.287870269993
# 1053 10653.533282626036
# 1054 10675.80406033132
# 1055 10698.100208201753
# 1056 10720.421731049573
# 1057 10742.768633683385
# 1058 10765.140920908147
# 1059 10787.538597525183
# 1060 10809.961668332184
# 1061 10832.410138123225
# 1062 10854.88401168876
# 1063 10877.383293815634
# 1064 10899.907989287081
# 1065 10922.458102882743
# 1066 10945.033639378671
# 1067 10967.634603547323
# 1068 10990.261000157585
# 1069 11012.912833974764
# 1070 11035.590109760598
# 1071 11058.292832273268
# 1072 11081.021006267387
# 1073 11103.77463649403
# 1074 11126.553727700724
# 1075 11149.358284631457
# 1076 11172.188312026687
# 1077 11195.04381462334
# 1078 11217.924797154825
# 1079 11240.831264351036
# 1080 11263.763220938365
# 1081 11286.720671639683
# 1082 11309.703621174383
# 1083 11332.712074258356
# 1084 11355.74603560401
# 1085 11378.805509920276
# 1086 11401.890501912607
# 1087 11425.00101628299
# 1088 11448.137057729951
# 1089 11471.298630948553
# 1090 11494.485740630415
# 1091 11517.698391463706
# 1092 11540.936588133158
# 1093 11564.200335320073
# 1094 11587.489637702314
# 1095 11610.804499954333
# 1096 11634.14492674716
# 1097 11657.510922748406
# 1098 11680.902492622288
# 1099 11704.31964102962
# 1100 11727.762372627816
# 1101 11751.230692070909
# 1102 11774.724604009542
# 1103 11798.24411309098
# 1104 11821.789223959118
# 1105 11845.359941254492
# 1106 11868.956269614257
# 1107 11892.578213672228
# 1108 11916.225778058864
# 1109 11939.89896740128
# 1110 11963.597786323247
# 1111 11987.322239445213
# 1112 12011.072331384286
# 1113 12034.848066754257
# 1114 12058.64945016559
# 1115 12082.476486225445
# 1116 12106.329179537675
# 1117 12130.207534702824
# 1118 12154.111556318147
# 1119 12178.041248977603
# 1120 12201.996617271865
# 1121 12225.97766578833
# 1122 12249.984399111108
# 1123 12274.016821821051
# 1124 12298.074938495742
# 1125 12322.1587537095
# 1126 12346.268272033396
# 1127 12370.403498035248
# 1128 12394.564436279628
# 1129 12418.751091327875
# 1130 12442.963467738091
# 1131 12467.201570065141
# 1132 12491.465402860682
# 1133 12515.75497067314
# 1134 12540.070278047735
# 1135 12564.411329526476
# 1136 12588.778129648168
# 1137 12613.170682948421
# 1138 12637.588993959653
# 1139 12662.033067211081
# 1140 12686.502907228758
# 1141 12710.998518535549
# 1142 12735.519905651145
# 1143 12760.067073092074
# 1144 12784.640025371698
# 1145 12809.238767000224
# 1146 12833.86330248471
# 1147 12858.513636329044
# 1148 12883.189773033999
# 1149 12907.891717097196
# 1150 12932.619473013126
# 1151 12957.37304527315
# 1152 12982.152438365505
# 1153 13006.957656775317
# 1154 13031.788704984585
# 1155 13056.645587472214
# 1156 13081.528308713992
# 1157 13106.436873182614
# 1158 13131.371285347685
# 1159 13156.331549675711
# 1160 13181.317670630122
# 1161 13206.329652671267
# 1162 13231.367500256414
# 1163 13256.431217839769
# 1164 13281.52080987246
# 1165 13306.636280802568
# 1166 13331.777635075108
# 1167 13356.944877132055
# 1168 13382.138011412322
# 1169 13407.357042351794
# 1170 13432.601974383311
# 1171 13457.872811936688
# 1172 13483.169559438697
# 1173 13508.492221313098
# 1174 13533.840801980637
# 1175 13559.215305859034
# 1176 13584.615737363009
# 1177 13610.042100904271
# 1178 13635.494400891534
# 1179 13660.972641730512
# 1180 13686.476827823935
# 1181 13712.006963571534
# 1182 13737.563053370068
# 1183 13763.14510161332
# 1184 13788.753112692091
# 1185 13814.387090994225
# 1186 13840.047040904594
# 1187 13865.732966805113
# 1188 13891.444873074746
# 1189 13917.182764089497
# 1190 13942.946644222433
# 1191 13968.73651784368
# 1192 13994.552389320419
# 1193 14020.39426301691
# 1194 14046.262143294472
# 1195 14072.156034511512
# 1196 14098.075941023517
# 1197 14124.021867183043
# 1198 14149.993817339755
# 1199 14175.991795840404
# 1200 14202.015807028836
# 1201 14228.065855246008
# 1202 14254.141944829978
# 1203 14280.24408011592
# 1204 14306.372265436112
# 1205 14332.526505119973
# 1206 14358.70680349402
# 1207 14384.913164881917
# 1208 14411.14559360446
# 1209 14437.404093979574
# 1210 14463.688670322332
# 1211 14489.999326944948
# 1212 14516.33606815679
# 1213 14542.698898264382
# 1214 14569.087821571393
# 1215 14595.502842378672
# 1216 14621.94396498422
# 1217 14648.411193683223
# 1218 14674.90453276803
# 1219 14701.42398652818
# 1220 14727.969559250383
# 1221 14754.541255218553
# 1222 14781.139078713775
# 1223 14807.763034014346
# 1224 14834.41312539576
# 1225 14861.08935713071
# 1226 14887.791733489106
# 1227 14914.52025873806
# 1228 14941.274937141909
# 1229 14968.055772962205
# 1230 14994.862770457734
# 1231 15021.695933884492
# 1232 15048.555267495727
# 1233 15075.440775541914
# 1234 15102.35246227077
# 1235 15129.290331927263
# 1236 15156.254388753596
# 1237 15183.244636989242
# 1238 15210.261080870925
# 1239 15237.303724632615
# 1240 15264.372572505568
# 1241 15291.467628718297
# 1242 15318.588897496593
# 1243 15345.736383063522
# 1244 15372.91008963943
# 1245 15400.110021441946
# 1246 15427.336182685998
# 1247 15454.588577583789
# 1248 15481.867210344824
# 1249 15509.172085175924
# 1250 15536.503206281193
# 1251 15563.860577862059
# 1252 15591.24420411725
# 1253 15618.654089242815
# 1254 15646.090237432125
# 1255 15673.552652875875
# 1256 15701.041339762074
# 1257 15728.556302276082
# 1258 15756.09754460058
# 1259 15783.665070915593
# 1260 15811.25888539849
# 1261 15838.878992223987
# 1262 15866.525395564144
# 1263 15894.19809958838
# 1264 15921.897108463469
# 1265 15949.622426353548
# 1266 15977.374057420122
# 1267 16005.152005822061
# 1268 16032.956275715607
# 1269 16060.78687125439
# 1270 16088.6437965894
# 1271 16116.527055869028
# 1272 16144.436653239043
# 1273 16172.372592842612
# 1274 16200.334878820297
# 1275 16228.323515310047
# 1276 16256.33850644723
# 1277 16284.379856364607
# 1278 16312.447569192358
# 1279 16340.541649058068
# 1280 16368.662100086756
# 1281 16396.808926400838
# 1282 16424.98213212016
# 1283 16453.181721362012
# 1284 16481.4076982411
# 1285 16509.660066869572
# 1286 16537.938831357016
# 1287 16566.243995810448
# 1288 16594.575564334362
# 1289 16622.933541030652
# 1290 16651.317929998713
# 1291 16679.728735335368
# 1292 16708.165961134917
# 1293 16736.62961148911
# 1294 16765.119690487165
# 1295 16793.63620221579
# 1296 16822.17915075914
# 1297 16850.748540198867
# 1298 16879.34437461409
# 1299 16907.96665808143
# 1300 16936.615394674984
# 1301 16965.29058846634
# 1302 16993.992243524586
# 1303 17022.720363916313
# 1304 17051.4749537056
# 1305 17080.25601695405
# 1306 17109.06355772075
# 1307 17137.897580062323
# 1308 17166.7580880329
# 1309 17195.64508568413
# 1310 17224.55857706518
# 1311 17253.49856622276
# 1312 17282.465057201083
# 1313 17311.458054041927
# 1314 17340.47756078457
# 1315 17369.523581465855
# 1316 17398.59612012017
# 1317 17427.69518077943
# 1318 17456.820767473117
# 1319 17485.972884228253
# 1320 17515.15153506943
# 1321 17544.3567240188
# 1322 17573.58845509605
# 1323 17602.84673231847
# 1324 17632.131559700894
# 1325 17661.442941255747
# 1326 17690.780880993025
# 1327 17720.14538292029
# 1328 17749.536451042706
# 1329 17778.95408936301
# 1330 17808.39830188154
# 1331 17837.86909259622
# 1332 17867.366465502557
# 1333 17896.890424593683
# 1334 17926.44097386031
# 1335 17956.018117290776
# 1336 17985.621858871014
# 1337 18015.252202584572
# 1338 18044.909152412616
# 1339 18074.59271233392
# 1340 18104.30288632489
# 1341 18134.039678359564
# 1342 18163.803092409587
# 1343 18193.593132444264
# 1344 18223.4098024305
# 1345 18253.25310633287
# 1346 18283.12304811357
# 1347 18313.019631732444
# 1348 18342.94286114698
# 1349 18372.892740312338
# 1350 18402.869273181295
# 1351 18432.872463704316
# 1352 18462.902315829513
# 1353 18492.958833502653
# 1354 18523.042020667188
# 1355 18553.151881264228
# 1356 18583.288419232544
# 1357 18613.451638508603
# 1358 18643.64154302654
# 1359 18673.85813671817
# 1360 18704.101423513
# 1361 18734.371407338214
# 1362 18764.668092118693
# 1363 18794.99148177702
# 1364 18825.34158023345
# 1365 18855.718391405957
# 1366 18886.12191921022
# 1367 18916.552167559614
# 1368 18947.009140365222
# 1369 18977.49284153585
# 1370 19008.00327497801
# 1371 19038.54044459594
# 1372 19069.10435429158
# 1373 19099.695007964612
# 1374 19130.312409512437
# 1375 19160.956562830186
# 1376 19191.627471810734
# 1377 19222.325140344677
# 1378 19253.04957232035
# 1379 19283.800771623846
# 1380 19314.57874213899
# 1381 19345.383487747342
# 1382 19376.215012328237
# 1383 19407.07331975875
# 1384 19437.958413913715
# 1385 19468.870298665726
# 1386 19499.808977885143
# 1387 19530.774455440078
# 1388 19561.76673519643
# 1389 19592.785821017846
# 1390 19623.831716765762
# 1391 19654.904426299396
# 1392 19686.003953475727
# 1393 19717.130302149533
# 1394 19748.283476173365
# 1395 19779.463479397575
# 1396 19810.6703156703
# 1397 19841.903988837465
# 1398 19873.16450274279
# 1399 19904.45186122781
# 1400 19935.766068131852
# 1401 19967.107127292045
# 1402 19998.475042543334
# 1403 20029.86981771847
# 1404 20061.29145664802
# 1405 20092.739963160373
# 1406 20124.215341081715
# 1407 20155.717594236077
# 1408 20187.246726445308
# 1409 20218.80274152908
# 1410 20250.385643304904
# 1411 20281.995435588116
# 1412 20313.632122191895
# 1413 20345.295706927252
# 1414 20376.98619360304
# 1415 20408.703586025957
# 1416 20440.44788800055
# 1417 20472.219103329222
# 1418 20504.017235812214
# 1419 20535.84228924763
# 1420 20567.69426743143
# 1421 20599.57317415745
# 1422 20631.47901321735
# 1423 20663.411788400692
# 1424 20695.3715034949
# 1425 20727.358162285258
# 1426 20759.371768554938
# 1427 20791.41232608497
# 1428 20823.479838654286
# 1429 20855.574310039687
# 1430 20887.695744015862
# 1431 20919.84414435537
# 1432 20952.0195148287
# 1433 20984.22185920419
# 1434 21016.451181248103
# 1435 21048.70748472459
# 1436 21080.990773395697
# 1437 21113.301051021386
# 1438 21145.63832135952
# 1439 21178.002588165862
# 1440 21210.393855194092
# 1441 21242.8121261958
# 1442 21275.25740492051
# 1443 21307.729695115646
# 1444 21340.229000526557
# 1445 21372.75532489652
# 1446 21405.308671966737
# 1447 21437.88904547634
# 1448 21470.49644916239
# 1449 21503.130886759885
# 1450 21535.79236200176
# 1451 21568.480878618895
# 1452 21601.1964403401
# 1453 21633.93905089214
# 1454 21666.708713999717
# 1455 21699.505433385508
# 1456 21732.3292127701
# 1457 21765.180055872068
# 1458 21798.057966407938
# 1459 21830.96294809219
# 1460 21863.895004637267
# 1461 21896.85413975359
# 1462 21929.84035714952
# 1463 21962.853660531422
# 1464 21995.894053603603
# 1465 22028.96154006836
# 1466 22062.05612362597
# 1467 22095.177807974687
# 1468 22128.32659681074
# 1469 22161.50249382835
# 1470 22194.705502719728
# 1471 22227.935627175073
# 1472 22261.192870882558
# 1473 22294.477237528383
# 1474 22327.788730796725
# 1475 22361.12735436976
# 1476 22394.493111927677
# 1477 22427.88600714866
# 1478 22461.306043708908
# 1479 22494.753225282613
# 1480 22528.227555542013
# 1481 22561.72903815731
# 1482 22595.257676796766
# 1483 22628.813475126644
# 1484 22662.39643681123
# 1485 22696.00656551283
# 1486 22729.643864891787
# 1487 22763.308338606468
# 1488 22796.99999031327
# 1489 22830.71882366661
# 1490 22864.464842318965
# 1491 22898.238049920838
# 1492 22932.03845012077
# 1493 22965.86604656535
# 1494 22999.72084289921
# 1495 23033.60284276503
# 1496 23067.512049803547
# 1497 23101.44846765353
# 1498 23135.412099951824
# 1499 23169.402950333322
# 1500 23203.42102243097
# 1501 23237.4663198758
# 1502 23271.538846296877
# 1503 23305.638605321346
# 1504 23339.765600574425
# 1505 23373.919835679408
# 1506 23408.101314257634
# 1507 23442.31003992855
# 1508 23476.546016309654
# 1509 23510.809247016554
# 1510 23545.099735662916
# 1511 23579.417485860497
# 1512 23613.762501219142
# 1513 23648.1347853468
# 1514 23682.534341849478
# 1515 23716.9611743313
# 1516 23751.415286394487
# 1517 23785.896681639355
# 1518 23820.405363664315
# 1519 23854.94133606589
# 1520 23889.504602438697
# 1521 23924.09516637548
# 1522 23958.713031467058
# 1523 23993.358201302395
# 1524 24028.03067946856
# 1525 24062.730469550726
# 1526 24097.4575751322
# 1527 24132.211999794403
# 1528 24166.993747116878
# 1529 24201.802820677294
# 1530 24236.63922405146
# 1531 24271.502960813283
# 1532 24306.39403453483
# 1533 24341.312448786295
# 1534 24376.258207136005
# 1535 24411.231313150423
# 1536 24446.231770394163
# 1537 24481.259582429968
# 1538 24516.31475281875
# 1539 24551.397285119525
# 1540 24586.5071828895
# 1541 24621.644449684016
# 1542 24656.809089056565
# 1543 24692.001104558803
# 1544 24727.22049974054
# 1545 24762.46727814974
# 1546 24797.741443332547
# 1547 24833.04299883324
# 1548 24868.37194819429
# 1549 24903.728294956334
# 1550 24939.11204265816
# 1551 24974.52319483676
# 1552 25009.961755027267
# 1553 25045.427726763013
# 1554 25080.92111357551
# 1555 25116.44191899445
# 1556 25151.990146547683
# 1557 25187.565799761276
# 1558 25223.168882159476
# 1559 25258.79939726471
# 1560 25294.457348597603
# 1561 25330.14273967698
# 1562 25365.85557401985
# 1563 25401.595855141437
# 1564 25437.363586555133
# 1565 25473.15877177257
# 1566 25508.981414303562
# 1567 25544.83151765613
# 1568 25580.709085336515
# 1569 25616.614120849157
# 1570 25652.546627696716
# 1571 25688.506609380067
# 1572 25724.494069398286
# 1573 25760.509011248687
# 1574 25796.551438426795
# 1575 25832.621354426366
# 1576 25868.718762739365
# 1577 25904.843666856003
# 1578 25940.996070264697
# 1579 25977.175976452123
# 1580 26013.38338890317
# 1581 26049.61831110096
# 1582 26085.880746526866
# 1583 26122.170698660484
# 1584 26158.48817097966
# 1585 26194.833166960492
# 1586 26231.205690077306
# 1587 26267.605743802684
# 1588 26304.033331607454
# 1589 26340.48845696069
# 1590 26376.971123329728
# 1591 26413.481334180153
# 1592 26450.019092975814
# 1593 26486.584403178804
# 1594 26523.177268249496
# 1595 26559.79769164651
# 1596 26596.44567682674
# 1597 26633.121227245338
# 1598 26669.824346355723
# 1599 26706.555037609607
# 1600 26743.313304456948
# 1601 26780.099150345995
# 1602 26816.91257872325
# 1603 26853.753593033536
# 1604 26890.622196719905
# 1605 26927.51839322374
# 1606 26964.442185984663
# 1607 27001.39357844062
# 1608 27038.372574027813
# 1609 27075.379176180766
# 1610 27112.413388332276
# 1611 27149.47521391341
# 1612 27186.564656353592
# 1613 27223.681719080472
# 1614 27260.82640552007
# 1615 27297.998719096642
# 1616 27335.1986632328
# 1617 27372.42624134943
# 1618 27409.68145686572
# 1619 27446.9643131992
# 1620 27484.27481376567
# 1621 27521.612961979292
# 1622 27558.978761252474
# 1623 27596.372214996023
# 1624 27633.793326618983
# 1625 27671.242099528787
# 1626 27708.718537131143
# 1627 27746.222642830086
# 1628 27783.754420028017
# 1629 27821.31387212561
# 1630 27858.90100252192
# 1631 27896.515814614286
# 1632 27934.158311798423
# 1633 27971.828497468334
# 1634 28009.526375016416
# 1635 28047.251947833356
# 1636 28085.005219308186
# 1637 28122.786192828316
# 1638 28160.594871779456
# 1639 28198.431259545705
# 1640 28236.295359509462
# 1641 28274.187175051524
# 1642 28312.106709551008
# 1643 28350.053966385374
# 1644 28388.02894893048
# 1645 28426.031660560493
# 1646 28464.062104647983
# 1647 28502.120284563833
# 1648 28540.206203677342
# 1649 28578.31986535612
# 1650 28616.461272966182
# 1651 28654.630429871893
# 1652 28692.827339435964
# 1653 28731.05200501954
# 1654 28769.30442998207
# 1655 28807.58461768143
# 1656 28845.892571473833
# 1657 28884.228294713907
# 1658 28922.591790754614
# 1659 28960.983062947354
# 1660 28999.402114641867
# 1661 29037.84894918628
# 1662 29076.32356992714
# 1663 29114.82598020933
# 1664 29153.356183376192
# 1665 29191.91418276939
# 1666 29230.499981729037
# 1667 29269.11358359361
# 1668 29307.754991699978
# 1669 29346.424209383447
# 1670 29385.121239977674
# 1671 29423.846086814774
# 1672 29462.598753225204
# 1673 29501.37924253789
# 1674 29540.187558080106
# 1675 29579.023703177587
# 1676 29617.88768115445
# 1677 29656.77949533321
# 1678 29695.69914903485
# 1679 29734.646645578705
# 1680 29773.621988282586
# 1681 29812.625180462677
# 1682 29851.65622543362
# 1683 29890.71512650844
# 1684 29929.80188699864
# 1685 29968.9165102141
# 1686 30008.058999463137
# 1687 30047.22935805253
# 1688 30086.427589287443
# 1689 30125.653696471523
# 1690 30164.907682906796
# 1691 30204.189551893785
# 1692 30243.499306731403
# 1693 30282.836950717006
# 1694 30322.202487146435
# 1695 30361.59591931391
# 1696 30401.017250512166
# 1697 30440.466484032313
# 1698 30479.94362316397
# 1699 30519.448671195158
# 1700 30558.981631412393
# 1701 30598.542507100607
# 1702 30638.13130154319
# 1703 30677.74801802203
# 1704 30717.392659817404
# 1705 30757.065230208118
# 1706 30796.765732471387
# 1707 30836.49416988292
# 1708 30876.250545716874
# 1709 30916.03486324588
# 1710 30955.84712574104
# 1711 30995.687336471885
# 1712 31035.555498706497
# 1713 31075.45161571135
# 1714 31115.37569075145
# 1715 31155.32772709022
# 1716 31195.307727989642
# 1717 31235.31569671009
# 1718 31275.351636510466
# 1719 31315.415550648162
# 1720 31355.50744237901
# 1721 31395.62731495738
# 1722 31435.775171636076
# 1723 31475.951015666447
# 1724 31516.154850298277
# 1725 31556.386678779887
# 1726 31596.646504358057
# 1727 31636.93433027807
# 1728 31677.250159783725
# 1729 31717.593996117288
# 1730 31757.96584251956
# 1731 31798.365702229792
# 1732 31838.79357848581
# 1733 31879.24947452386
# 1734 31919.73339357877
# 1735 31960.245338883826
# 1736 32000.78531367082
# 1737 32041.35332117011
# 1738 32081.949364610497
# 1739 32122.573447219344
# 1740 32163.22557222249
# 1741 32203.905742844334
# 1742 32244.61396230776
# 1743 32285.35023383417
# 1744 32326.114560643517
# 1745 32366.906945954233
# 1746 32407.727392983328
# 1747 32448.57590494628
# 1748 32489.452485057154
# 1749 32530.357136528477
# 1750 32571.28986257137
# 1751 32612.250666395437
# 1752 32653.239551208833
# 1753 32694.25652021827
# 1754 32735.301576628943
# 1755 32776.37472364465
# 1756 32817.47596446766
# 1757 32858.605302298856
# 1758 32899.76274033759
# 1759 32940.94828178181
# 1760 32982.161929828006
# 1761 33023.40368767115
# 1762 33064.67355850486
# 1763 33105.97154552123
# 1764 33147.297651910936
# 1765 33188.651880863195
# 1766 33230.03423556581
# 1767 33271.44471920509
# 1768 33312.88333496591
# 1769 33354.35008603174
# 1770 33395.84497558458
# 1771 33437.368006805016
# 1772 33478.91918287214
# 1773 33520.49850696369
# 1774 33562.10598225588
# 1775 33603.74161192359
# 1776 33645.4053991402
# 1777 33687.09734707765
# 1778 33728.81745890651
# 1779 33770.56573779586
# 1780 33812.342186913425
# 1781 33854.14680942544
# 1782 33895.97960849676
# 1783 33937.840587290775
# 1784 33979.72974896952
# 1785 34021.64709669356
# 1786 34063.59263362203
# 1787 34105.566362912716
# 1788 34147.56828772192
# 1789 34189.5984112046
# 1790 34231.656736514225
# 1791 34273.743266802914
# 1792 34315.858005221366
# 1793 34358.00095491884
# 1794 34400.172119043236
# 1795 34442.371500741
# 1796 34484.599103157234
# 1797 34526.85492943558
# 1798 34569.138982718345
# 1799 34611.45126614635
# 1800 34653.79178285912
# 1801 34696.160535994706
# 1802 34738.55752868978
# 1803 34780.98276407966
# 1804 34823.43624529821
# 1805 34865.917975477976
# 1806 34908.42795775005
# 1807 34950.9661952442
# 1808 34993.53269108871
# 1809 35036.12744841061
# 1810 35078.75047033544
# 1811 35121.4017599874
# 1812 35164.08132048931
# 1813 35206.78915496261
# 1814 35249.52526652736
# 1815 35292.28965830222
# 1816 35335.08233340454
# 1817 35377.90329495022
# 1818 35420.75254605382
# 1819 35463.63008982856
# 1820 35506.53592938622
# 1821 35549.47006783729
# 1822 35592.43250829082
# 1823 35635.42325385457
# 1824 35678.442307634854
# 1825 35721.4896727367
# 1826 35764.56535226373
# 1827 35807.66934931819
# 1828 35850.801667001026
# 1829 35893.96230841176
# 1830 35937.15127664863
# 1831 35980.36857480843
# 1832 36023.614205986705
# 1833 36066.88817327754
# 1834 36110.19047977377
# 1835 36153.52112856681
# 1836 36196.880122746734
# 1837 36240.267465402314
# 1838 36283.683159620916
# 1839 36327.12720848862
# 1840 36370.59961509012
# 1841 36414.1003825088
# 1842 36457.62951382667
# 1843 36501.187012124414
# 1844 36544.7728804814
# 1845 36588.38712197563
# 1846 36632.02973968381
# 1847 36675.70073668125
# 1848 36719.40011604199
# 1849 36763.12788083868
# 1850 36806.88403414272
# 1851 36850.6685790241
# 1852 36894.48151855151
# 1853 36938.32285579235
# 1854 36982.192593812644
# 1855 37026.09073567712
# 1856 37070.017284449175
# 1857 37113.972243190896
# 1858 37157.95561496304
# 1859 37201.967402825045
# 1860 37246.00760983505
# 1861 37290.07623904983
# 1862 37334.1732935249
# 1863 37378.29877631444
# 1864 37422.45269047134
# 1865 37466.63503904711
# 1866 37510.84582509206
# 1867 37555.085051655085
# 1868 37599.35272178381
# 1869 37643.64883852461
# 1870 37687.97340492247
# 1871 37732.32642402114
# 1872 37776.70789886301
# 1873 37821.11783248922
# 1874 37865.556227939574
# 1875 37910.02308825261
# 1876 37954.51841646554
# 1877 37999.04221561429
# 1878 38043.594488733506
# 1879 38088.17523885651
# 1880 38132.78446901537
# 1881 38177.42218224083
# 1882 38222.08838156238
# 1883 38266.78307000818
# 1884 38311.50625060515
# 1885 38356.257926378865
# 1886 38401.03810035365
# 1887 38445.84677555258
# 1888 38490.68395499738
# 1889 38535.54964170855
# 1890 38580.443838705265
# 1891 38625.36654900547
# 1892 38670.31777562581
# 1893 38715.297521581604
# 1894 38760.305789887
# 1895 38805.34258355478
# 1896 38850.40790559652
# 1897 38895.50175902245
# 1898 38940.624146841634
# 1899 38985.775072061755
# 1900 39030.95453768932
# 1901 39076.16254672952
# 1902 39121.399102186275
# 1903 39166.66420706228
# 1904 39211.95786435893
# 1905 39257.28007707639
# 1906 39302.630848213536
# 1907 39348.01018076801
# 1908 39393.418077736176
# 1909 39438.85454211316
# 1910 39484.31957689281
# 1911 39529.81318506772
# 1912 39575.335369629276
# 1913 39620.88613356754
# 1914 39666.4654798714
# 1915 39712.073411528414
# 1916 39757.70993152498
# 1917 39803.37504284618
# 1918 39849.068748475845
# 1919 39894.791051396634
# 1920 39940.54195458988
# 1921 39986.32146103574
# 1922 40032.129573713064
# 1923 40077.96629559953
# 1924 40123.83162967152
# 1925 40169.725578904225
# 1926 40215.64814627157
# 1927 40261.599334746206
# 1928 40307.579147299664
# 1929 40353.58758690212
# 1930 40399.624656522596
# 1931 40445.690359128836
# 1932 40491.7846976874
# 1933 40537.90767516355
# 1934 40584.05929452142
# 1935 40630.239558723835
# 1936 40676.44847073239
# 1937 40722.68603350755
# 1938 40768.95225000843
# 1939 40815.24712319303
# 1940 40861.57065601807
# 1941 40907.92285143908
# 1942 40954.30371241034
# 1943 41000.71324188492
# 1944 41047.15144281473
# 1945 41093.61831815035
# 1946 41140.11387084129
# 1947 41186.63810383572
# 1948 41233.19102008069
# 1949 41279.772622521945
# 1950 41326.38291410413
# 1951 41373.02189777061
# 1952 41419.689576463534
# 1953 41466.3859531239
# 1954 41513.111030691456
# 1955 41559.86481210477
# 1956 41606.6473003012
# 1957 41653.458498216896
# 1958 41700.2984087868
# 1959 41747.1670349447
# 1960 41794.064379623116
# 1961 41840.99044575342
# 1962 41887.94523626579
# 1963 41934.92875408915
# 1964 41981.94100215134
# 1965 42028.98198337888
# 1966 42076.05170069719
# 1967 42123.15015703047
# 1968 42170.277355301696
# 1969 42217.43329843273
# 1970 42264.617989344166
# 1971 42311.831430955484
# 1972 42359.07362618491
# 1973 42406.34457794955
# 1974 42453.64428916528
# 1975 42500.97276274683
# 1976 42548.33000160771
# 1977 42595.71600866026
# 1978 42643.13078681569
# 1979 42690.57433898395
# 1980 42738.04666807389
# 1981 42785.54777699313
# 1982 42833.077668648155
# 1983 42880.63634594424
# 1984 42928.223811785516
# 1985 42975.84006907494
# 1986 43023.48512071426
# 1987 43071.15896960413
# 1988 43118.86161864394
# 1989 43166.593070732
# 1990 43214.353328765406
# 1991 43262.14239564012
# 1992 43309.96027425091
# 1993 43357.806967491364
# 1994 43405.682478253984
# 1995 43453.58680943002
# 1996 43501.51996390964
# 1997 43549.48194458179
# 1998 43597.472754334325
# 1999 43645.492396053865
# 2000 43693.54087262595
# 2001 43741.61818693492
# 2002 43789.72434186394
# 2003 43837.85934029511
# 2004 43886.02318510926

# %%
DM = 333
n, t, t2 = [], [], []
for i in range(int(head['nbands'][0])):
    n.append((float((head['fbands'][i])[0:-1:]))**-2)

for i in range(int(head['nbands'][0])):
    t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM*10**-3))) #в секундах 

for i in range(int(head['nbands'][0])):
    if t[i] == 0:
        t2.append(0)
    else:
        t2.append(abs(round(t[i] / (float(head['tresolution'][0])/1000)))) # в точках
        
t4 = [abs(i)*1000 for i in t]

# %%
t4
# Out:
# [4289.903993046386,
#  3414.3990453891993,
#  2548.7820737860748,
#  1692.904736784577,
#  846.6214643460028,
#  0.0]

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(dm_list, t_s_list)
ax.loglog()
plt.ylabel('$\mathregular{τ_s}$, ms', size=15)
plt.xlabel(' DM, pc $\mathregular{cm^{-3}}$', size=15)
matplotlib.rc('xtick', labelsize=15)
matplotlib.rc('ytick', labelsize=15)
plt.title('scattering_kuzmin', size=15)
ax.grid(which='both', color='grey', linewidth=0.5, linestyle='--')
plt.grid(True)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
DM = 100
n, t, t2 = [], [], []
for i in range(int(head['nbands'][0])):
    n.append((float((head['fbands'][i])[0:-1:]))**-2)

for i in range(int(head['nbands'][0])):
    t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM*10**-3))) #в секундах 

for i in range(int(head['nbands'][0])):
    if t[i] == 0:
        t2.append(0)
    else:
        t2.append(abs(round(t[i] / (float(head['tresolution'][0])/1000)))) # в точках

# %%
#fig, ax = plt.subplots(figsize=(8, 6))
#for k in range(9,len(dm_list),100):
for k in range(1764,1770,1):
    
    DM = dm_list[k]
    
    n, t, t2 = [], [], []
    for i in range(int(head['nbands'][0])):
        n.append((float((head['fbands'][i])[0:-1:]))**-2)

    for i in range(int(head['nbands'][0])):
        t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM*10**-3)))

    for i in range(int(head['nbands'][0])):
        if t[i] == 0:
            t2.append(0)
        else:
            t2.append(abs(round(t[i] / (float(head['tresolution'][0])/1000))))
            
            
    t2.sort()
    t3 = [abs(i) for i in t]
    t3.sort()
    print(t3)
            
    lenth = int(DM*20*i)
    x = [i for i in range(-1,int(lenth))]
                                                 
    fig, ax = plt.subplots(figsize=(8, 6))
    
    t_s = scattering_kuz (dm_list[k])
    #if t_s < 

    
    x_scatter = scatter(x,t_s,t2[1])
    
    norm = 1/max(x_scatter)
    for i in range (len((x_scatter))):
        x_scatter[i]*=norm
        
    time_plot = [i/1000 for i in range(len(x_scatter))]
    
    plt.plot(time_plot[:int(t_s*11.5)],x_scatter[:int(t_s*11.5)], 'r')
    #plt.plot(x_scatter, 'r')
    
    plt.title('pattern_kuz, DM = ' + str(dm_list[k]) + ', ' + '$\mathregular{τ_s}$ = ' + ' ' + str(round(t_s,2)) + ' ms', size=15)
    ax.tick_params(axis='both', which='major', labelsize=10, length = 5,    #  Длинна делений
               width = 1)
    
    plt.ylabel('$\mathregular{τ_s}$, ms', size=15)
    plt.xlabel(' DM, pc $\mathregular{cm^{-3}}$', size=15)
    matplotlib.rc('xtick', labelsize=15)
    matplotlib.rc('ytick', labelsize=15)
    ax.grid(which='both', color='grey', linewidth=0.5, linestyle='--')
    plt.grid(True)
    
    plt.ylabel('amplitude(acp)', size=15)
    plt.xlabel('time (s)', size=15)
    plt.show();
# Out:
# [0.0, 4.492432815313474, 8.983071080775819, 13.524618391531515, 18.11784718679494, 22.763544611750643]
# <img src="data:image/png;base64,..." width="799.5333333333333">
# [0.0, 4.494975222113311, 8.988154878784181, 13.532272391753093, 18.128100637381696, 22.77642720632436]
# <img src="data:image/png;base64,..." width="799.5333333333333">
# [0.0, 4.497517628913149, 8.993238676792542, 13.539926391974674, 18.13835408796845, 22.78930980089807]
# <img src="data:image/png;base64,..." width="799.5333333333333">
# [0.0, 4.500060035712987, 8.998322474800906, 13.547580392196254, 18.148607538555204, 22.80219239547178]
# <img src="data:image/png;base64,..." width="799.5333333333333">
# [0.0, 4.502602442512825, 9.003406272809267, 13.555234392417834, 18.15886098914196, 22.8150749900455]
# <img src="data:image/png;base64,..." width="799.5333333333333">
# [0.0, 4.5051448493126625, 9.00849007081763, 13.562888392639413, 18.169114439728713, 22.82795758461921]
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %% [markdown]
# ## Шаблоны импульса с учетом рассеяния в зависимости от DM по Бхату

# %%
def scattering_bhat (a, b, c, DM):
    t = a + (b*(math.log10(DM))) + c*(math.log10(DM)**2)# - (4.4*(math.log10(0.111)))   
    #t_s = a + b*(np.log(DM)) + c*(np.log(DM))**2
    t_s = pow(10, t)
    print(t_s)
    return t_s

def scatter (x,t_s, t):
    a = []
    for i in range(len(x)):
        if x[i] < 0:
            a.append(0)
        else:
            a.append((1/t_s)*(np.exp(-x[i]/t_s)))
    return a

def pulse (x,a,b,s):
    c = []
    for i in range(len(x)):
        c.append(a*np.exp(-(((x[i] - b)**2)/(2*s**2))))
        
    return c

# %%
t_s_list = []
dm_list = [i for i in range(3,2005)]

a, b, c = -6.46, 0.154, 1.07
a, b, c =  -6.59, 0.129, 1.02
for i in range(len(dm_list)):
    DM = dm_list[i]
    t = scattering_bhat (a, b, c, DM)
    t_s_list.append(t)
# Out:
# 5.055291782947343e-07
# 7.200978209085547e-07
# 9.965460655647586e-07
# 1.3427997976858e-06
# 1.7680402935626325e-06
# 2.2823464204118524e-06
# 2.8965939941781814e-06
# 3.62242998416698e-06
# 4.472273508177266e-06
# 5.45932797499552e-06
# 6.597598463893985e-06
# 7.90191184391139e-06
# 9.38793848156902e-06
# 1.1072214967681874e-05
# 1.2972167565137994e-05
# 1.5106136213973756e-05
# 1.7493399000300617e-05
# 2.0154197033996944e-05
# 2.3109759701850902e-05
# 2.6382330275633817e-05
# 2.9995191862318984e-05
# 3.397269368847471e-05
# 3.834027771392369e-05
# 4.312450557175429e-05
# 4.835308583309713e-05
# 5.40549015959723e-05
# 6.026003839813315e-05
# 6.699981245426432e-05
# 7.430679921819583e-05
# 8.22148622710191e-05
# 9.075918253615254e-05
# 9.997628782252312e-05
# 0.00010990408269711953
# 0.0001205818786882455
# 0.0001320504248208521
# 0.00014435193848536595
# 0.00015753013664147276
# 0.00017163026735833223
# 0.00018669914169272154
# 0.00020278516590664135
# 0.00021993837402589696
# 0.00023821046074122012
# 0.0002576548146534782
# 0.0002783265518645377
# 0.0003002825499153642
# 0.0003235814820729282
# 0.0003482838519675189
# 0.0003744520285820519
# 0.00040215028159497037
# 0.00043144481707835356
# 0.00046240381355282673
# 0.0004950974584009097
# 0.0005295979846403934
# 0.0005659797080594032
# 0.0006043190647147271
# 0.000644694648795101
# 0.0006871872508510176
# 0.0007318798963927573
# 0.0007788578848582351
# 0.0008282088289523421
# 0.0008800226943593958
# 0.0009343918398303932
# 0.000991411057646676
# 0.0010511776144616943
# 0.0011137912925225089
# 0.0011793544312727281
# 0.00124797196933851
# 0.0013197514868993217
# 0.0013948032484451043
# 0.0014732402459215696
# 0.0015551782422652365
# 0.001640735815329964
# 0.0017300344022065988
# 0.0018231983439374792
# 0.0019203549306274423
# 0.0020216344469530787
# 0.0021271702180718655
# 0.0022370986559329393
# 0.0023515593059911907
# 0.0024706948943263723
# 0.0025946513751689323
# 0.002723577978834329
# 0.0028576272600674855
# 0.0029969551467990876
# 0.0031417209893155624
# 0.0032920876098443204
# 0.003448221352556057
# 0.0036102921339858677
# 0.003778473493874876
# 0.003952942646434026
# 0.004133880532032031
# 0.0043214718693088995
# 0.004515905207717047
# 0.004717372980491549
# 0.004926071558051466
# 0.00514220130183382
# 0.005365966618562112
# 0.0055975760149511045
# 0.005837242152849523
# 0.006085181904822655
# 0.006341616410176483
# 0.006606771131425065
# 0.006880875911203105
# 0.007164165029625282
# 0.007456877262094442
# 0.00775925593756006
# 0.008071548997228964
# 0.008394009053730162
# 0.0087268934507355
# 0.009070464323037635
# 0.0094249886570881
# 0.009790738351995608
# 0.010167990280988479
# 0.010557026353341027
# 0.010958133576767087
# 0.01137160412028179
# 0.011797735377533713
# 0.012236830030609007
# 0.012689196114309935
# 0.013155147080908378
# 0.013635001865377451
# 0.014129084951102662
# 0.014637726436073946
# 0.015161262099561127
# 0.015700033469273997
# 0.016254387889009573
# 0.016824678586787642
# 0.01741126474347729
# 0.01801451156191501
# 0.018634790336517822
# 0.01927247852339218
# 0.019927959810940674
# 0.020601624190968466
# 0.021293868030292023
# 0.02200509414285072
# 0.022735711862324124
# 0.023486137115256822
# 0.024256792494692172
# 0.025048107334316953
# 0.025860517783120065
# 0.026694466880564604
# 0.027550404632277523
# 0.028428788086258067
# 0.029330081409607002
# 0.030254755965777026
# 0.031203290392349325
# 0.03217617067933494
# 0.033173890248005766
# 0.03419695003025414
# 0.03524585854848634
# 0.036321131996047765
# 0.03742329431818659
# 0.03855287729355293
# 0.03971042061624018
# 0.0408964719783652
# 0.04211158715319544
# 0.043356330078818346
# 0.044631272942361896
# 0.045936996264760395
# 0.047274088986076594
# 0.04864314855137307
# 0.05004478099714145
# 0.05147960103828723
# 0.05294823215567692
# 0.05445130668424212
# 0.0559894659016508
# 0.05756336011754163
# 0.059173648763326696
# 0.06082100048256128
# 0.06250609322188944
# 0.06422961432255672
# 0.06599226061250217
# 0.06779473849902774
# 0.06963776406204392
# 0.07152206314789811
# 0.07344837146378894
# 0.07541743467275855
# 0.07743000848928114
# 0.07948685877543415
# 0.0815887616376623
# 0.08373650352413733
# 0.08593088132270926
# 0.08817270245945744
# 0.09046278499784043
# 0.09280195773844696
# 0.09519106031935148
# 0.09763094331707235
# 0.10012246834814043
# 0.10266650817127802
# 0.105263946790184
# 0.10791567955693869
# 0.11062261327602091
# 0.11338566630894546
# 0.11620576867951814
# 0.11908386217971179
# 0.12202090047616969
# 0.12501784921733483
# 0.12807568614120154
# 0.13119540118370657
# 0.13437799658774366
# 0.13762448701281843
# 0.14093589964533754
# 0.14431327430953658
# 0.147757663579048
# 0.1512701328891144
# 0.15485176064944106
# 0.15850363835770365
# 0.16222687071369885
# 0.16602257573414791
# 0.16989188486815282
# 0.17383594311330816
# 0.17785590913247695
# 0.18195295537121262
# 0.18612826817585398
# 0.19038304791228414
# 0.19471850908534377
# 0.19913588045893235
# 0.20363640517675605
# 0.20822134088377134
# 0.21289195984828918
# 0.21764954908475218
# 0.22249541047721227
# 0.22743086090346282
# 0.23245723235987123
# 0.2375758720868964
# 0.242788142695283
# 0.24809542229295353
# 0.2534991046125993
# 0.259000599139946
# 0.2646013312427361
# 0.27030274230039675
# 0.2761062898344166
# 0.282013447639415
# 0.28802570591493165
# 0.2941445713979074
# 0.3003715674958885
# 0.3067082344209314
# 0.31315612932423104
# 0.31971682643145705
# 0.32639191717881205
# 0.33318301034981834
# 0.3400917322128091
# 0.3471197266591582
# 0.35426865534224494
# 0.36154019781712
# 0.36893605168093957
# 0.376457932714101
# 0.3841075750221359
# 0.391886731178333
# 0.39979717236710666
# 0.40784068852809496
# 0.4160190885010277
# 0.4243342001713167
# 0.4327878706164146
# 0.44138196625290976
# 0.45011837298439134
# 0.45899899635006225
# 0.46802576167410476
# 0.4772006142158257
# 0.48652551932054977
# 0.49600246257128006
# 0.5056334499411289
# 0.5154205079465303
# 0.5253656838012031
# 0.5354710455709081
# 0.5457386823289685
# 0.5561707043125828
# 0.5667692430799087
# 0.5775364516679393
# 0.58847450475116
# 0.599585598800994
# 0.6108719522460492
# 0.6223358056331438
# 0.6339794217891347
# 0.6458050859835537
# 0.657815106092021
# 0.6700118127604875
# 0.6823975595702674
# 0.6949747232038663
# 0.7077457036116623
# 0.7207129241793468
# 0.7338788318962164
# 0.7472458975242655
# 0.7608166157681023
# 0.7745935054456906
# 0.7885791096599077
# 0.8027759959709361
# 0.8171867565694795
# 0.8318140084508114
# 0.8466603935896564
# 0.8617285791159133
# 0.8770212574912046
# 0.8925411466862834
# 0.9082909903592705
# 0.9242735580347299
# 0.9404916452836302
# 0.9569480739040991
# 0.9736456921030885
# 0.9905873746788371
# 1.0077760232042692
# 1.0252145662111483
# 1.0429059593752024
# 1.0608531857020211
# 1.0790592557138972
# 1.097527207637484
# 1.1162601075923384
# 1.1352610497803701
# 1.1545331566761132
# 1.174079579217928
# 1.1939034970000566
# 1.2140081184655571
# 1.2343966811001714
# 1.2550724516270149
# 1.2760387262022126
# 1.2972988306113906
# 1.3188561204671165
# 1.340713981407185
# 1.3628758292938177
# 1.385345110413796
# 1.4081253016794777
# 1.4312199108307264
# 1.4546324766377248
# 1.4783665691048071
# 1.5024257896750313
# 1.526813771435867
# 1.5515341793256523
# 1.5765907103410324
# 1.6019870937453615
# 1.6277270912779918
# 1.6538144973644613
# 1.6802531393277123
# 1.707046877600158
# 1.734199605936722
# 1.7617152516288397
# 1.7895977757193757
# 1.8178511732184814
# 1.8464794733204606
# 1.8754867396214954
# 1.9048770703384321
# 1.9346545985284143
# 1.9648234923095766
# 1.9953879550826374
# 2.0263522257534814
# 2.0577205789567183
# 2.089497325280137
# 2.1216868114903
# 2.1542934207589295
# 2.1873215728903865
# 2.2207757245500357
# 2.254660369493767
# 2.2889800387982406
# 2.3237393010924343
# 2.3589427627898796
# 2.3945950683220802
# 2.430700900372906
# 2.4672649801139204
# 2.504292067440733
# 2.5417869612104154
# 2.5797544994798383
# 2.61819955974509
# 2.657127059181821
# 2.6965419548867224
# 2.7364492441199273
# 2.7768539645484442
# 2.8177611944906804
# 2.859176053161868
# 2.9011037009206815
# 2.9435493395167254
# 2.9865182123391723
# 3.0300156046663136
# 3.0740468439164057
# 3.118617299899127
# 3.16373238506857
# 3.2093975547768556
# 3.255618307529167
# 3.3024001852394305
# 3.3497487734875038
# 3.397669701777024
# 3.446168643794574
# 3.495251317669759
# 3.5449234862364642
# 3.5951909572951344
# 3.646059583876037
# 3.6975352645038373
# 3.749623943462896
# 3.8023316110640155
# 3.855664303912012
# 3.9096281051744697
# 3.964229144851603
# 4.019473600047144
# 4.0753676952403834
# 4.131917702559259
# 4.18912994205456
# 4.247010781975307
# 4.305566639045076
# 4.364803978739549
# 4.424729315565231
# 4.485349213339049
# 4.546670285469317
# 4.608699195237725
# 4.67144265608239
# 4.734907431882014
# 4.799100337241423
# 4.8640282377778785
# 4.92969805040875
# 4.996116743640343
# 5.0632913378576045
# 5.131228905615275
# 5.199936571930088
# 5.269421514573952
# 5.339690964368579
# 5.410752205480934
# 5.482612575720124
# 5.55527946683536
# 5.628760324814862
# 5.703062650186288
# 5.778193998318151
# 5.854161979722263
# 5.9309742603576385
# 6.008638561935332
# 6.087162662224627
# 6.166554395360319
# 6.246821652151145
# 6.327972380389448
# 6.410014585162087
# 6.492956329162433
# 6.576805733003575
# 6.6615709755329355
# 6.747260294147613
# 6.833881985111498
# 6.921444403873175
# 7.00995596538515
# 7.099425144424433
# 7.189860475914168
# 7.281270555246593
# 7.373664038606909
# 7.467049643299077
# 7.561436148071969
# 7.656832393447349
# 7.753247282048962
# 7.850689778932712
# 7.9491689119182025
# 8.048693771921501
# 8.149273513289135
# 8.250917354133303
# 8.353634576668373
# 8.457434527548708
# 8.562326618207535
# 8.668320325197412
# 8.775425190531541
# 8.883650822026635
# 8.993006893646998
# 9.103503145849906
# 9.215149385932051
# 9.327955488377649
# 9.441931395207355
# 9.557087116328933
# 9.673432729888933
# 9.790978382625406
# 9.909734290222875
# 10.029710737667163
# 10.150918079602885
# 10.273366740691582
# 10.397067215970804
# 10.522030071215484
# 10.64826594329971
# 10.775785540560271
# 10.90459964316152
# 11.034719103461285
# 11.166154846378406
# 11.298917869761286
# 11.433019244758261
# 11.56847011618857
# 11.70528170291558
# 11.843465298220357
# 11.98303227017733
# 12.12399406203109
# 12.266362192574233
# 12.41014825652718
# 12.555363924918503
# 12.702020945467545
# 12.850131142967603
# 12.999706419670998
# 13.150758755675223
# 13.303300209310496
# 13.457342917528885
# 13.61289909629468
# 13.769981040975932
# 13.92860112673776
# 14.088771808936691
# 14.25050562351677
# 14.41381518740667
# 14.578713198918447
# 14.745212438147448
# 14.913325767374106
# 15.08306613146638
# 15.254446558284505
# 15.427480159086373
# 15.602180128934776
# 15.778559747105609
# 15.956632377498444
# 16.136411469047363
# 16.31791055613374
# 16.50114325900088
# 16.686123284169263
# 16.872864424853777
# 17.061380561382244
# 17.25168566161543
# 17.443793781368377
# 17.637719064833135
# 17.833475745003337
# 18.03107814409997
# 18.230540673998146
# 18.431877836656152
# 18.635104224545778
# 18.840234521083524
# 19.04728350106374
# 19.25626603109343
# 19.467197070028263
# 19.680091669409343
# 19.894964973903587
# 20.11183222174302
# 20.330708745167268
# 20.551609970866824
# 20.774551420428143
# 20.999548710780022
# 21.226617554641955
# 21.45577376097285
# 21.687033235422366
# 21.92041198078391
# 22.15592609744782
# 22.393591783857264
# 22.63342533696561
# 22.875443152694462
# 23.11966172639381
# 23.366097653304404
# 23.614767629019827
# 23.865688449952085
# 24.11887701379732
# 24.374350320004453
# 24.63212547024307
# 24.892219668875516
# 25.15465022342941
# 25.419434545070896
# 25.68659014908067
# 25.95613465533109
# 26.22808578876508
# 26.502461379876014
# 26.77927936518987
# 27.05855778774866
# 27.340314797595344
# 27.624568652260514
# 27.911337717250728
# 28.20064046653807
# 28.492495483051727
# 28.786921459170962
# 29.08393719721967
# 29.38356160996247
# 29.68581372110292
# 29.990712665782503
# 30.298277691081775
# 30.60852815652326
# 30.921483534575657
# 31.23716341115936
# 31.555587486154632
# 31.876775573910546
# 32.20074760375573
# 32.52752362051068
# 32.85712378500212
# 33.18956837457879
# 33.52487778362849
# 33.86307252409807
# 34.20417322601264
# 34.54820063799901
# 34.895175627810204
# 35.245119182849365
# 35.59805241069914
# 35.95399653964969
# 36.31297291922891
# 36.67500302073689
# 37.04010843777707
# 37.40831088679528
# 37.779632207614036
# 38.154094363974714
# 38.531719444075925
# 38.91252966111788
# 39.29654735384571
# 39.68379498709608
# 40.07429515234417
# 40.468070568253765
# 40.86514408122815
# 41.26553866596345
# 41.66927742600245
# 42.07638359429146
# 42.48688053373794
# 42.90079173777182
# 43.31814083090462
# 43.738951569294535
# 44.16324784131152
# 44.59105366810267
# 45.02239320416261
# 45.45729073790249
# 45.89577069222271
# 46.337857625086194
# 46.78357623009525
# 47.23295133706794
# 47.686007912616404
# 48.14277106073096
# 48.603266023358806
# 49.067518180992224
# 49.5355530532519
# 50.00739629947767
# 50.48307371931656
# 50.96261125331526
# 51.44603498351353
# 51.93337113404034
# 52.42464607170951
# 52.91988630661961
# 53.41911849275517
# 53.922369428588695
# 54.42966605768507
# 54.94103546930823
# 55.456504899029035
# 55.97610172933539
# 56.49985349024437
# 57.027787859915016
# 57.559932665265016
# 58.09631588258637
# 58.636965638167155
# 59.18191020891028
# 59.7311780229574
# 60.28479766031369
# 60.84279785347545
# 61.405207488056384
# 61.97205560342082
# 62.54337139331361
# 63.11918420649665
# 63.69952354738239
# 64.28441907667491
# 64.87390061200732
# 65.46799812858471
# 66.06674175982774
# 66.67016179801823
# 67.27828869494745
# 67.89115306256359
# 68.50878567362541
# 69.13121746235454
# 69.75847952509123
# 70.39060312095026
# 71.02761967248159
# 71.66956076633113
# 72.31645815390249
# 72.96834375202408
# 73.62524964361435
# 74.28720807834988
# 74.95425147334132
# 75.62641241379725
# 76.30372365370903
# 76.98621811651914
# 77.6739288958055
# 78.36688925595787
# 79.0651326328655
# 79.76869263459646
# 80.47760304208886
# 81.19189780983606
# 81.91161106657908
# 82.63677711599979
# 83.36743043741335
# 84.10360568646745
# 84.84533769583926
# 85.59266147593682
# 86.34561221560102
# 87.1042252828122
# 87.86853622539422
# 88.63858077172578
# 89.41439483145024
# 90.19601449618757
# 90.9834760402507
# 91.7768159213635
# 92.57607078137522
# 93.38127744698745
# 94.192472930474
# 95.00969443040587
# 95.83297933237998
# 96.66236520974756
# 97.49788982434598
# 98.33959112723309
# 99.18750725942023
# 100.04167655261453
# 100.90213752995265
# 101.76892890674672
# 102.64208959123009
# 103.52165868529794
# 104.40767548525896
# 105.30017948258575
# 106.19921036466594
# 107.10480801555778
# 108.0170125167462
# 108.93586414790082
# 109.86140338764038
# 110.793670914291
# 111.73270760665521
# 112.67855454477699
# 113.63125301071128
# 114.59084448929822
# 115.55737066893408
# 116.53087344234898
# 117.5113949073841
# 118.49897736777092
# 119.49366333391933
# 120.49549552369224
# 121.5045168632033
# 122.52077048759709
# 123.54429974184586
# 124.57514818154183
# 125.613359573691
# 126.65897789751239
# 127.71204734523712
# 128.77261232291252
# 129.84071745120517
# 130.91640756620657
# 131.9997277202434
# 133.09072318268775
# 134.1894394407745
# 135.29592220040965
# 136.41021738699388
# 137.53237114623892
# 138.66242984499343
# 139.8004400720644
# 140.94644863904574
# 142.10050258114646
# 143.26264915802312
# 144.43293585461169
# 145.61141038196556
# 146.79812067809027
# 147.99311490878802
# 149.19644146849856
# 150.40814898114337
# 151.6282863009727
# 152.85690251341663
# 154.09404693594044
# 155.3397691188867
# 156.59411884634656
# 157.85714613701
# 159.12890124502732
# 160.40943466087435
# 161.6987971122197
# 162.99703956478916
# 164.30421322323858
# 165.62036953202582
# 166.9455601762883
# 168.27983708271307
# 169.62325242042982
# 170.9758586018743
# 172.3377082836946
# 173.70885436762052
# 175.08935000135847
# 176.47924857949005
# 177.87860374435408
# 179.28746938695193
# 180.70589964784054
# 182.13394891803915
# 183.57167183993081
# 185.01912330816307
# 186.4763584705632
# 187.94343272904882
# 189.42040174053443
# 190.90732141785534
# 192.40424793067766
# 193.9112377064271
# 195.4283474312056
# 196.95563405071712
# 198.49315477119748
# 200.0409670603473
# 201.59912864825577
# 203.16769752834483
# 204.74673195830096
# 206.33629046101902
# 207.93643182554126
# 209.54721510800564
# 211.16869963258839
# 212.80094499246093
# 214.44401105073385
# 216.09795794142195
# 217.76284607038832
# 219.43873611631622
# 221.12568903166724
# 222.82376604364245
# 224.53302865515525
# 226.25353864579787
# 227.98535807281635
# 229.7285492720804
# 231.4831748590656
# 233.24929772983282
# 235.02698106200964
# 236.81628831577615
# 238.61728323484516
# 240.43002984746937
# 242.2545924674151
# 244.09103569496907
# 245.93942441793516
# 247.7998238126272
# 249.67229934488358
# 251.55691677105992
# 253.45374213904577
# 255.36284178927716
# 257.2842823557399
# 259.21813076699215
# 261.1644542471874
# 263.12332031707956
# 265.09479679506586
# 267.0789517982027
# 269.07585374322883
# 271.08557134761355
# 273.1081736305739
# 275.14372991412006
# 277.1923098240972
# 279.2539832912157
# 281.3288205521112
# 283.416892150383
# 285.5182689376357
# 287.6330220745529
# 289.7612230319344
# 291.9029435917621
# 294.0582558482594
# 296.22723220895165
# 298.40994539573234
# 300.6064684459413
# 302.8168747134219
# 305.04123786960054
# 307.2796319045697
# 309.5321311281566
# 311.79881017101053
# 314.07974398569087
# 316.3750078477519
# 318.6846773568243
# 321.00882843772865
# 323.34753734154543
# 325.7008806467364
# 328.06893526023015
# 330.4517784185368
# 332.8494876888434
# 335.2621409701329
# 337.68981649429674
# 340.1325928272382
# 342.59054887000457
# 345.0637638598939
# 347.55231737159295
# 350.056289318289
# 352.575759952808
# 355.110809868739
# 357.6615200015835
# 360.2279716298733
# 362.8102463763129
# 365.40842620894125
# 368.0225934422585
# 370.65283073838015
# 373.29922110818717
# 375.9618479124855
# 378.64079486315023
# 381.33614602430896
# 384.0479858134724
# 386.7763990027329
# 389.52147071989964
# 392.2832864496997
# 395.06193203493376
# 397.8574936776585
# 400.6700579403672
# 403.4997117471701
# 406.3465423849757
# 409.21063750469864
# 412.09208512242446
# 414.99097362061576
# 417.9073917493154
# 420.84142862734205
# 423.7931737434784
# 426.7627169577055
# 429.7501485023881
# 432.7555589834955
# 435.77903938181095
# 438.82068105415857
# 441.88057573462066
# 444.9588155357488
# 448.055492949804
# 451.17070084998505
# 454.30453249165765
# 457.45708151358286
# 460.6284419391657
# 463.8187081776966
# 467.02797502558116
# 470.2563376676065
# 473.5038916781801
# 476.7707330225788
# 480.0569580582235
# 483.362663535911
# 486.68794660110444
# 490.0329047951686
# 493.39763605666985
# 496.78223872262623
# 500.1868115297825
# 503.6114536158951
# 507.05626452100773
# 510.5213441887371
# 514.0067929675573
# 517.5127116120877
# 521.0392012843905
# 524.5863635552643
# 528.1543004055324
# 531.7431142273621
# 535.3529078255578
# 538.9837844188745
# 542.6358476413209
# 546.3092015434722
# 550.0039505938123
# 553.7201996800148
# 557.4580541102963
# 561.2176196147379
# 564.9990023465871
# 568.8023088836425
# 572.6276462295322
# 576.4751218150997
# 580.3448434997085
# 584.2369195726282
# 588.1514587543376
# 592.0885701979049
# 596.0483634903362
# 600.0309486539384
# 604.0364361476596
# 608.0649368684827
# 612.1165621527687
# 616.1914237776356
# 620.2896339623368
# 624.4113053696283
# 628.5565511071588
# 632.7254847288478
# 636.9182202362676
# 641.1348720800343
# 645.3755551612155
# 649.6403848327077
# 653.9294769006427
# 658.2429476257878
# 662.5809137249573
# 666.943492372418
# 671.3308012012952
# 675.7429583050038
# 680.1800822386507
# 684.6422920204704
# 689.129707133227
# 693.6424475256833
# 698.1806336139923
# 702.7443862831525
# 707.3338268884444
# 711.9490772568666
# 716.590259688585
# 721.2574969583939
# 725.9509123171307
# 730.6706294931743
# 735.4167726938779
# 740.1894666070273
# 744.9888364023349
# 749.8150077328609
# 754.6681067365408
# 759.54826003761
# 764.4555947481082
# 769.3902384693683
# 774.3523192934769
# 779.3419658047835
# 784.3593070813674
# 789.4044726965731
# 794.4775927204819
# 799.5787977213937
# 804.7082187673847
# 809.8659874277657
# 815.0522357746308
# 820.2670963843557
# 825.5107023391125
# 830.7831872283978
# 836.0846851505753
# 841.4153307143612
# 846.7752590404122
# 852.1646057628144
# 857.58350703066
# 863.0320995095619
# 868.5105203832057
# 874.0189073549136
# 879.5573986491961
# 885.1261330132814
# 890.7252497187211
# 896.3548885629094
# 902.0151898706825
# 907.7062944958692
# 913.4283438228802
# 919.1814797682739
# 924.965844782352
# 930.781581850718
# 936.6288344959
# 942.5077467789226
# 948.4184633008979
# 954.3611292046397
# 960.3358901762515
# 966.3428924467363
# 972.3822827936325
# 978.4542085425826
# 984.5588175689708
# 990.6962582995494
# 996.8666797140694
# 1003.0702313468763
# 1009.3070632885602
# 1015.5773261876184
# 1021.8811712520323
# 1028.21875025097
# 1034.5902155163917
# 1040.9957199447103
# 1047.4354169984626
# 1053.9094607079262
# 1060.4180056728221
# 1066.9612070639525
# 1073.5392206248719
# 1080.1522026735663
# 1086.8003101041152
# 1093.4837003883754
# 1100.2025315776898
# 1106.9569623045063
# 1113.747151784138
# 1120.57325981643
# 1127.4354467874202
# 1134.3338736711128
# 1141.268702031111
# 1148.2400940223824
# 1155.248212392912
# 1162.2932204854715
# 1169.3752822393117
# 1176.4945621918846
# 1183.6512254805878
# 1190.8454378444499
# 1198.0773656259316
# 1205.3471757726156
# 1212.655035838955
# 1220.0011139880137
# 1227.3855789932384
# 1234.808600240214
# 1242.2703477283567
# 1249.7709920727655
# 1257.310704505916
# 1264.889656879477
# 1272.5080216660326
# 1280.1659719609074
# 1287.8636814839092
# 1295.601324581131
# 1303.3790762267213
# 1311.197112024716
# 1319.0556082107698
# 1326.954741653993
# 1334.8946898587676
# 1342.875630966517
# 1350.897743757539
# 1358.961207652817
# 1367.0662027158255
# 1375.212909654371
# 1383.4015098223874
# 1391.6321852218202
# 1399.9051185044002
# 1408.2204929734846
# 1416.5784925859805
# 1424.9793019540468
# 1433.4231063471111
# 1441.9100916935631
# 1450.4404445827288
# 1459.0143522666492
# 1467.6320026620097
# 1476.2935843519801
# 1484.999286588067
# 1493.749299292035
# 1502.543813057751
# 1511.3830191530585
# 1520.2671095217406
# 1529.1962767853008
# 1538.1707142449766
# 1547.1906158835122
# 1556.256176367208
# 1565.3675910476998
# 1574.5250559639474
# 1583.7287678440966
# 1592.978924107472
# 1602.2757228664543
# 1611.6193629283714
# 1621.0100437975257
# 1630.4479656770573
# 1639.9333294708892
# 1649.4663367857286
# 1659.0471899329332
# 1668.6760919305336
# 1678.353246505155
# 1688.078858093995
# 1697.853131846757
# 1707.676273627658
# 1717.5484900173828
# 1727.4699883150754
# 1737.4409765402957
# 1747.4616634349957
# 1757.5322584655912
# 1767.6529718248448
# 1777.8240144339325
# 1788.0455979444391
# 1798.317934740316
# 1808.6412379399874
# 1819.015721398255
# 1829.441599708396
# 1839.9190882041387
# 1850.4484029617372
# 1861.0297608019453
# 1871.663379292108
# 1882.34947674814
# 1893.088272236636
# 1903.8799855768648
# 1914.7248373428667
# 1925.6230488654498
# 1936.5748422343224
# 1947.5804403000918
# 1958.6400666763795
# 1969.7539457419
# 1980.9223026424743
# 1992.1453632931778
# 2003.4233543804114
# 2014.756503363963
# 2026.1450384791535
# 2037.5891887388602
# 2049.089183935712
# 2060.645254644105
# 2072.257632222404
# 2083.9265488149863
# 2095.6522373543967
# 2107.4349315634677
# 2119.2748659574363
# 2131.1722758460874
# 2143.127397335902
# 2155.1404673322068
# 2167.211723541257
# 2179.3414044724527
# 2191.529749440487
# 2203.7769985674704
# 2216.0833927851377
# 2228.4491738369793
# 2240.874584280455
# 2253.3598674891095
# 2265.9052676547985
# 2278.5110297898796
# 2291.177399729401
# 2303.9046241332276
# 2316.6929504883774
# 2329.5426271110937
# 2342.4539031490967
# 2355.427028583825
# 2368.462254232619
# 2381.559831750976
# 2394.7200136347033
# 2407.9430532222727
# 2421.2292046968914
# 2434.578723088903
# 2447.991864277925
# 2461.4688849951544
# 2475.010042825565
# 2488.6155962101916
# 2502.285804448461
# 2516.0209277003314
# 2529.821226988615
# 2543.686964201341
# 2557.618402093861
# 2571.6158042912903
# 2585.67943529074
# 2599.809560463581
# 2614.006446057747
# 2628.2703592001203
# 2642.601567898741
# 2657.0003410451095
# 2671.4669484166484
# 2686.001660678859
# 2700.604749387691
# 2715.2764869919315
# 2730.0171468354793
# 2744.827003159728
# 2759.706331105844
# 2774.6554067172256
# 2789.6745069417043
# 2804.7639096340386
# 2819.9238935582334
# 2835.154738389854
# 2850.4567247184928
# 2865.8301340500516
# 2881.2752488092124
# 2896.7923523417126
# 2912.3817289168346
# 2928.043663729806
# 2943.778442904082
# 2959.5863534938767
# 2975.467683486559
# 2991.422721804935
# 3007.451758309829
# 3023.555083802451
# 3039.732990026765
# 3055.985769672012
# 3072.313716375082
# 3088.7171247230203
# 3105.1962902553937
# 3121.7515094668274
# 3138.38307980939
# 3155.0912996950674
# 3171.876468498315
# 3188.738886558413
# 3205.6788551819636
# 3222.6966766455066
# 3239.7926541977627
# 3256.967092062325
# 3274.220295440115
# 3291.5525705118384
# 3308.96422444047
# 3326.4555653738266
# 3344.0269024470986
# 3361.678545785232
# 3379.410806505623
# 3397.223996720596
# 3415.118429539828
# 3433.0944190730406
# 3451.1522804324673
# 3469.292329735402
# 3487.514884106751
# 3505.82026168161
# 3524.208781607905
# 3542.6807640487154
# 3561.236530185198
# 3579.87640221879
# 3598.6007033741716
# 3617.4097579014942
# 3636.30389107927
# 3655.2834292167668
# 3674.3486996567367
# 3693.5000307779023
# 3712.7377519977836
# 3732.0621937750175
# 3751.4736876122347
# 3770.972566058621
# 3790.5591627124218
# 3810.2338122237175
# 3829.9968502971387
# 3849.848613694272
# 3869.7894402364996
# 3889.8196688075955
# 3909.93963935644
# 3930.1496928996407
# 3950.4501715241618
# 3970.841418390108
# 3991.3237777333993
# 4011.8975948683224
# 4032.5632161903286
# 4053.32098917882
# 4074.171262399696
# 4095.114385508108
# 4116.150709251251
# 4137.280585470944
# 4158.504367106534
# 4179.822408197449
# 4201.2350638860335
# 4222.742690420293
# 4244.345645156595
# 4266.044286562453
# 4287.838974219209
# 4309.73006882497
# 4331.717932197156
# 4353.802927275418
# 4375.985418124376
# 4398.265769936334
# 4420.644349034227
# 4443.121522874286
# 4465.697660048813
# 4488.373130289079
# 4511.148304468098
# 4534.0235546034
# 4556.9992538598935
# 4580.075776552738
# 4603.2534981499975
# 4626.532795275713
# 4649.914045712529
# 4673.397628404698
# 4696.983923460761
# 4720.673312156652
# 4744.466176938299
# 4768.362901424655
# 4792.363870410515
# 4816.469469869385
# 4840.680086956362
# 4864.996110011077
# 4889.417928560486
# 4913.945933321958
# 4938.580516205924
# 4963.322070318937
# 4988.170989966599
# 5013.127670656455
# 5038.1925091008625
# 5063.365903220027
# 5088.648252144781
# 5114.039956219819
# 5139.5414170062195
# 5165.153037284759
# 5190.875221058779
# 5216.708373556991
# 5242.652901236725
# 5268.709211786584
# 5294.877714129664
# 5321.158818426435
# 5347.552936077863
# 5374.060479728157
# 5400.68186326803
# 5427.417501837522
# 5454.267811829032
# 5481.233210890634
# 5508.314117928538
# 5535.5109531106855
# 5562.824137869396
# 5590.254094904575
# 5617.801248186839
# 5645.466022960272
# 5673.248845745914
# 5701.150144344369
# 5729.170347839204
# 5757.309886599866
# 5785.56919228488
# 5813.948697844749
# 5842.448837525189
# 5871.070046870302
# 5899.812762725418
# 5928.677423240463
# 5957.664467872847
# 5986.77433739093
# 6016.007473876603
# 6045.364320728982
# 6074.845322667199
# 6104.450925733651
# 6134.181577297182
# 6164.037726056108
# 6194.019822041551
# 6224.128316620462
# 6254.363662498868
# 6284.7263137250075
# 6315.216725692529
# 6345.835355143753
# 6376.582660172651
# 6407.459100228381
# 6438.465136118094
# 6469.6012300105085
# 6500.867845438876
# 6532.265447304347
# 6563.794501879127
# 6595.455476809782
# 6627.2488411203385
# 6659.175065215679
# 6691.234620884821
# 6723.427981303908
# 6755.755621039726
# 6788.2180160530315
# 6820.815643701506
# 6853.548982743377
# 6886.418513340392
# 6919.424717061468
# 6952.568076885669
# 6985.8490772057
# 7019.268203831141
# 7052.8259439917365
# 7086.522786340759
# 7120.3592209584585
# 7154.335739355143
# 7188.452834474722
# 7222.711000698016
# 7257.110733845908
# 7291.652531183092
# 7326.336891421026
# 7361.164314721674
# 7396.135302700538
# 7431.250358430245
# 7466.5099864440135
# 7501.914692738714
# 7537.464984778582
# 7573.161371498544
# 7609.004363307732
# 7644.994472092442
# 7681.132211220167
# 7717.418095542749
# 7753.852641399583
# 7790.43636662157
# 7827.1697905341925
# 7864.053433961033
# 7901.087819227247
# 7938.273470163257
# 7975.610912107622
# 8013.100671911353
# 8050.743277940735
# 8088.539260081079
# 8126.489149740127
# 8164.593479851763
# 8202.85278487914
# 8241.267600818723
# 8279.83846520329
# 8318.565917105803
# 8357.450497142765
# 8396.492747477869
# 8435.693211825439
# 8475.05243545411
# 8514.570965190278
# 8554.249349421685
# 8594.088138101142
# 8634.087882749787
# 8674.249136461049
# 8714.572453903786
# 8755.058391326551
# 8795.707506560431
# 8836.52035902311
# 8877.497509722532
# 8918.639521260187
# 8959.94695783505
# 9001.420385247058
# 9043.060370900765
# 9084.867483809114
# 9126.84229459689
# 9168.985375504533
# 9211.29730039179
# 9253.778644741202
# 9296.429985662122
# 9339.2519018941
# 9382.244973810602
# 9425.409783423067
# 9468.746914384028
# 9512.256951991376
# 9555.940483191696
# 9599.798096584067
# 9643.830382424063
# 9688.037932627134
# 9732.421340772406
# 9776.981202106746
# 9821.718113548179
# 9866.632673689677
# 9911.725482803133
# 9956.997142842994
# 10002.448257450056
# 10048.079431955177
# 10093.891273383373
# 10139.88439045713
# 10186.05939360074
# 10232.416894943626
# 10278.957508324555
# 10325.681849295332
# 10372.590535124475
# 10419.684184801332
# 10466.963419039665
# 10514.428860281738
# 10562.081132702036
# 10609.920862211007
# 10657.94867645936
# 10706.165204841484
# 10754.571078499599
# 10803.166930327605
# 10851.95339497486
# 10900.93110885032
# 10950.10071012621
# 10999.462838742054
# 11049.018136408637
# 11098.767246612011
# 11148.710814616934
# 11198.84948747168
# 11249.183914011273
# 11299.714744861803
# 11350.442632444121
# 11401.368230978022
# 11452.492196486372
# 11503.81518679869
# 11555.337861555427
# 11607.060882212008
# 11658.984912042424
# 11711.11061614393
# 11763.438661440447
# 11815.96971668679
# 11868.704452472894
# 11921.643541227719
# 11974.787657223056
# 12028.137476578122
# 12081.693677263027
# 12135.45693910335
# 12189.427943783841
# 12243.607374852703
# 12297.995917725539
# 12352.594259689808
# 12407.403089908346
# 12462.423099423999
# 12517.65498116354
# 12573.09942994143
# 12628.757142464903
# 12684.628817337125
# 12740.715155061695
# 12797.01685804691
# 12853.534630609922
# 12910.269178980645
# 12967.2212113063
# 13024.391437655124
# 13081.780570021168
# 13139.38932232797
# 13197.218410432672
# 13255.268552131101
# 13313.540467160692
# 13372.034877206026
# 13430.752505901964
# 13489.69407883851
# 13548.860323564972
# 13608.251969594083
# 13667.86974840597
# 13727.714393453434
# 13787.786640164795
# 13848.087225949434
# 13908.616890201407
# 13969.376374303787
# 14030.366421633225
# 14091.587777563884
# 14153.041189472275
# 14214.727406741034
# 14276.647180763368
# 14338.801264947942
# 14401.190414722332
# 14463.815387538163
# 14526.676942874774
# 14589.775842244433
# 14653.112849195755
# 14716.688729318728
# 14780.504250249087
# 14844.560181672048
# 14908.857295327787
# 14973.396365014909
# 15038.178166595117
# 15103.20347799805
# 15168.473079225016
# 15233.987752354184
# 15299.748281544233
# 15365.755453039696
# 15432.010055174362
# 15498.512878376805
# 15565.26471517421
# 15632.266360196798
# 15699.518610183013
# 15767.022263982884
# 15834.778122563726
# 15902.786989013744
# 15971.04966854719
# 16039.56696850848
# 16108.339698376716
# 16177.368669770522
# 16246.65469645224
# 16316.198594333111
# 16386.001181476906
# 16456.06327810511
# 16526.3857066015
# 16596.96929151669
# 16667.81485957224
# 16738.923239666005
# 16810.29526287636
# 16881.931762466633
# 16953.833573890257
# 17026.001534794683
# 17098.436485026767
# 17171.139266636812
# 17244.110723883525
# 17317.351703238837
# 17390.86305339203
# 17464.645625254907
# 17538.700271966314
# 17613.027848896596
# 17687.62921365286
# 17762.50522608306
# 17837.65674828125
# 17913.08464459153
# 17988.789781613825
# 18064.773028207856
# 18141.035255497944
# 18217.577336878232
# 18294.40014801694
# 18371.50456686137
# 18448.891473642423
# 18526.561750880064
# 18604.51628338697
# 18682.755958274793
# 18761.281664957478
# 18840.09429515677
# 18919.194742907614
# 18998.583904562092
# 19078.26267879411
# 19158.231966605348
# 19238.49267132907
# 19319.045698635524
# 19399.891956536456
# 19481.03235539054
# 19562.46780790743
# 19644.19922915339
# 19726.227536556147
# 19808.55364990881
# 19891.178491376362
# 19974.102985499347
# 20057.32805919911
# 20140.85464178328
# 20224.683664949745
# 20308.816062792415
# 20393.25277180592
# 20477.99473089071
# 20563.042881356985
# 20648.39816693208
# 20734.06153376225
# 20820.033930421032
# 20906.31630791119
# 20992.909619671897
# 21079.81482158285
# 21167.032871969357
# 21254.564731607556
# 21342.41136372921
# 21430.573734027028
# 21519.05281066002
# 21607.849564257176
# 21696.96496792449
# 21786.399997248584
# 21876.15563030279
# 21966.232847651165
# 22056.63263235475
# 22147.35596997589
# 22238.40384858371
# 22329.777258759088
# 22421.477193600203
# 22513.504648727063
# 22605.860622286822
# 22698.54611495959
# 22791.562129962756
# 22884.90967305698
# 22978.58975255014
# 23072.603379304055
# 23166.95156673899
# 23261.635330838297
# 23356.655690154537
# 23452.013665814753
# 23547.7102815247
# 23643.74656357517
# 23740.123540846478
# 23836.842244814496
# 23933.903709555136
# 24031.3089717503
# 24129.059070692736
# 24227.15504829156
# 24325.597949077073
# 24424.388820207107
# 24523.52871147155
# 24623.018675297462
# 24722.859766755388
# 24823.05304356366
# 24923.59956609471
# 25024.50039737936
# 25125.75660311337
# 25227.369251661956
# 25329.33941406563
# 25431.6681640451
# 25534.356578007737
# 25637.405735051223
# 25740.816716971003
# 25844.59060826441
# 25948.728496136235
# 26053.231470504896
# 26158.100624006594
# 26263.337052002415
# 26368.941852582608
# 26474.916126572163
# 26581.260977537182
# 26687.97751178941
# 26795.066838392035
# 26902.530069165357
# 27010.36831869246
# 27118.582704324195
# 27227.174346185457
# 27336.14436717968
# 27445.493892995728
# 27555.22405211282
# 27665.33597580532
# 27775.83079815
# 27886.709656029805
# 27997.97368914155
# 28109.624039999024
# 28221.661853941383
# 28334.08827913587
# 28446.904466585893
# 28560.111570135698
# 28673.710746475732
# 28787.703155148687
# 28902.089958554898
# 29016.87232195888
# 29132.051413493675
# 29247.62840416766
# 29363.60446786978
# 29479.980781374903
# 29596.75852435086
# 29713.938879362442
# 29831.523031878332
# 29949.512170277067
# 30067.907485851123
# 30186.710172814543
# 30305.921428308146
# 30425.54245240467
# 30545.574448115516
# 30666.01862139586
# 30786.876181150055
# 30908.14833923974
# 31029.836310486393
# 31151.941312680097
# 31274.464566583043
# 31397.40729593743
# 31520.770727469113
# 31644.556090896094
# 31768.76461893266
# 31893.397547294735
# 32018.456114707806
# 32143.941562911703
# 32269.855136665454
# 32396.19808375581
# 32522.971655000696
# 32650.17710425635
# 32777.81568842309
# 32905.88866745175
# 33034.397304348386
# 33163.34286518189
# 33292.72661908858
# 33422.54983827899
# 33552.81379804339
# 33683.51977675845
# 33814.669055893275
# 33946.26292001411
# 34078.30265679169
# 34210.78955700784
# 34343.72491455918
# 34477.110026466034
# 34610.946192876225
# 34745.23471707288
# 34879.97690547915
# 35015.174067665044
# 35150.82751635378
# 35286.93856742759
# 35423.508539932845
# 35560.53875608878
# 35698.03054129119
# 35835.985224119584
# 35974.40413634299
# 36113.28861292724
# 36252.6399920395
# 36392.45961505582
# 36532.74882656691
# 36673.508974384014
# 36814.74140954522
# 36956.447486322446
# 37098.62856222711
# 37241.28599801617
# 37384.42115769897
# 37528.035408542666
# 37672.13012107946
# 37816.70666911306
# 37961.76642972358
# 38107.31078327458
# 38253.34111342051
# 38399.858807111144
# 38546.86525459955
# 38694.361849447145
# 38842.349988531
# 38990.831072049616
# 39139.80650352953
# 39289.27768983238
# 39439.246041160135
# 39589.71297106199
# 39740.679896440786
# 39892.148237559995
# 40044.1194180489
# 40196.594864910505
# 40349.57600852667
# 40503.06428266593
# 40657.06112448876
# 40811.56797455418
# 40966.58627682756
# 41122.11747868548
# 41278.16303092301
# 41434.72438776061
# 41591.80300684979
# 41749.40034928073
# 41907.51787958706
# 42066.157065754516
# 42225.31937922625
# 42385.006294910054
# 42545.21929118422
# 42705.95984990504
# 42867.22945641202
# 43029.02959953662
# 43191.361771607204
# 43354.22746845574
# 43517.62818942528
# 43681.56543737649
# 43846.04071869354
# 44011.05554329175
# 44176.61142462333
# 44342.70987968561
# 44509.35242902497
# 44676.540596747116
# 44844.275910521355
# 45012.559901587745
# 45181.394104764164
# 45350.78005845336
# 45520.71930464922
# 45691.21338894365
# 45862.26386053327
# 46033.8722722269
# 46206.0401804511
# 46378.7691452585
# 46552.060730333
# 46725.916502998094
# 46900.338034223474
# 47075.32689863044
# 47250.88467450044
# 47427.01294378142
# 47603.71329209463
# 47780.98730874103
# 47958.836586710095
# 48137.262722683095
# 48316.267317044585
# 48495.85197388579
# 48676.018301012875
# 48856.76790995442
# 49038.10241596749
# 49220.023438044474
# 49402.53259892104
# 49585.63152508301
# 49769.321846772255
# 49953.605197994955
# 50138.48321652785
# 50323.9575439256
# 50510.02982552798
# 50696.70171046671
# 50883.97485167307
# 51071.85090588334
# 51260.33153364849
# 51449.418399338254
# 51639.11317115123
# 51829.4175211202
# 52020.33312511894
# 52211.861662871976
# 52404.004817956935
# 52596.76427781757
# 52790.141733766395
# 52984.138880994265
# 53178.757418575755
# 53373.99904947859
# 53569.86548056861
# 53766.35842261909
# 53963.47959031642
# 54161.230702267574
# 54359.61348100852
# 54558.62965300954
# 54758.28094868524
# 54958.569102397945
# 55159.49585246953
# 55361.062941185446
# 55563.27211480191
# 55766.12512355718
# 55969.62372167383
# 56173.769667369204
# 56378.564722862044
# 56584.01065437902
# 56790.109232163835
# 56996.86223048313
# 57204.27142763515
# 57412.33860595482
# 57621.06555182471
# 57830.45405567865
# 58040.50591201362
# 58251.22291939147
# 58462.60688045234
# 58674.65960191797
# 58887.382894600414
# 59100.778573410345
# 59314.84845736459
# 59529.59436959135
# 59745.01813734082
# 59961.12159198959
# 60177.90656905297
# 60395.37490818621
# 60613.528453197585
# 60832.369052052316
# 61051.89855688263
# 61272.11882399368
# 61493.03171387235
# 61714.63909119399
# 61936.94282483098
# 62159.94478785896
# 62383.64685756713
# 62608.050915460735
# 62833.15884727638
# 63058.972542982796
# 63285.49389679153
# 63512.724807165556
# 63740.667176824994
# 63969.32291275562
# 64198.693926217165
# 64428.78213275082
# 64659.589452185784
# 64891.11780864853
# 65123.36913057155
# 65356.34535069683
# 65590.04840608922
# 65824.48023814024
# 66059.64279257815
# 66295.5380194741
# 66532.16787325124
# 66769.53431269208
# 67007.63930094679
# 67246.48480553995
# 67486.07279838044
# 67726.40525576747
# 67967.48415839896
# 68209.31149138042
# 68451.8892442322
# 68695.21941089671
# 68939.30398974816
# 69184.14498359899
# 69429.7443997081
# 69676.10424978896
# 69923.22655001974
# 70171.11332104704
# 70419.76658799789
# 70669.18838048489
# 70919.38073261689
# 71170.34568300493
# 71422.08527477212
# 71674.60155555978
# 71927.89657753624
# 72181.97239740597
# 72436.8310764183
# 72692.47468037122
# 72948.90527962473
# 73206.12494910628
# 73464.1357683195
# 73722.93982135228
# 73982.53919688537
# 74242.9359881998
# 74504.13229318551
# 74766.1302143512
# 75028.93185882845
# 75292.53933838496
# 75556.95476942828
# 75822.18027301769
# 76088.21797487081
# 76355.07000537112
# 76622.73849957908
# 76891.22559723613
# 77160.53344277757
# 77430.66418533832
# 77701.61997876041
# 77973.4029816054
# 78246.01535715749
# 78519.45927343567
# 78793.73690320119
# 79068.85042396544
# 79344.80201799833
# 79621.59387233798
# 79899.22817879698
# 80177.70713397306
# 80457.03293925627
# 80737.20780083833
# 81018.23392972008
# 81300.11354172054
# 81582.84885748623
# 81866.44210249718
# 82150.89550707908
# 82436.2113064089
# 82722.39174052486
# 83009.43905433381
# 83297.35549762183
# 83586.14332506126
# 83875.80479621951
# 84166.34217556784
# 84457.75773248973
# 84750.05374129076
# 85043.23248120547
# 85337.29623640806
# 85632.24729601758
# 85928.08795411194
# 86224.8205097312
# 86522.44726689105
# 86820.97053458657
# 87120.39262680514
# 87420.71586253303
# 87721.9425657671
# 88024.07506551743
# 88327.11569582271
# 88631.06679575608
# 88935.93070943278
# 89241.70978602298
# 89548.4063797539
# 89856.02284992649
# 90164.56156092006
# 90474.02488219902

# %%
fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(dm_list, t_s_list)
ax.loglog()
plt.ylabel('t_s', size=15)
plt.xlabel('dm', size=15)
plt.title('scattering_bhat', size=15)
ax.grid(which='both', color='grey', linewidth=0.5, linestyle='--')
plt.grid(True)
plt.show();
# Out:
# <img src="data:image/png;base64,..." width="799.5333333333333">

# %%
#fig, ax = plt.subplots(figsize=(8, 6))
for k in range(97,len(dm_list),100):

    DM = dm_list[k]
    
    n, t, t2 = [], [], []
    for i in range(int(head['nbands'][0])):
        n.append((float((head['fbands'][i])[0:-1:]))**-2)

    for i in range(int(head['nbands'][0])):
        t.append(((4.148808 * (10**6) * (n[len(n) - 1] - n[i]) * DM)))

    for i in range(int(head['nbands'][0])):
        if t[i] == 0:
            t2.append(0)
        else:
            t2.append(abs(round(t[i] / (float(head['tresolution'][0])/1000))))
            
            
    t2.sort()
    
            
    lenth = int(DM*200*i)
    x = [i for i in range(-1,int(lenth))]
                                                 
    fig, ax = plt.subplots(figsize=(8, 6))
    
    t_s = scattering_bhat (a,b,c,dm_list[k])
    x_scatter = scatter(x,t_s,t2[1])
    
    norm = 1/max(x_scatter)
    for i in range (len((x_scatter))):
        x_scatter[i]*=norm
        
    time_plot = [i/10 for i in range(len(x_scatter))]
    print(DM, t_s, len(time_plot))
    
    if int(round(t_s)*11.5) > 1:
        plt.plot(time_plot[:int(round(t_s)*11.5)],x_scatter[:int(round(t_s)*11.5)], 'r')
        
    else:
        plt.plot(time_plot[:10],x_scatter[:10], 'r')
        
    #plt.plot(x_scatter, 'r')
    
    plt.title('pattern_bhat, DM = ' + str(dm_list[k]) + ', ' + '$\mathregular{τ_s}$ = ' + ' ' + str(round(t_s,2)) + ' ms', size=15)
    ax.tick_params(axis='both', which='major', labelsize=10, length = 5,    #  Длинна делений
               width = 1)
    
    plt.ylabel('$\mathregular{τ_s}$, ms', size=15)
    plt.xlabel(' DM, pc $\mathregular{cm^{-3}}$', size=15)
    matplotlib.rc('xtick', labelsize=15)
    matplotlib.rc('ytick', labelsize=15)
    ax.grid(which='both', color='grey', linewidth=0.5, linestyle='--')
    plt.grid(True)
    
    plt.ylabel('amplitude(acp)', size=15)
    plt.xlabel('time (ms)', size=15)
    plt.show();
